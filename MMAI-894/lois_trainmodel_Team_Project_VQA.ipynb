# %% [markdown]
# #STEP 1: Import Libraries

# %%
# step 1: Import libraries
# !pip install torch torchvision transformers
# !pip install tqdm
import pandas as pd
from PIL import Image
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import zipfile
from google.colab import drive
import random
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import cv2
import re
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import numpy as np
import nltk
import numpy as np
nltk.download('punkt')
import numpy as np
from tensorflow.keras.preprocessing import image
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import torch.nn.functional as F
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.19.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Define the data path
drive.mount('/content/drive')
data_path = '/content/drive/My Drive/Colab Notebooks/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #STEP 2: LOAD TRAIN DATA

# %%
# Define function for loading questions and annotations

def load_data(data_file, feature):

  # Check if the file exists
  if os.path.exists(data_file):
    print("File found:", data_file)

    # Load the JSON file using the json module
    with open(data_file, 'r') as f:
        data = json.load(f)

    # Convert the JSON data to a DataFrame
    # questions = pd.DataFrame(data)

    # Flatten the JSON structure
    data = pd.json_normalize(data[feature])

    # Question preprocessing

    print("Data loaded successfully")
  else:
    print("File not found:", data_file)

  return data

# %%
# Load training questions

# Define the questions file
train_questions_file = os.path.join(data_path, 'train2015/MultipleChoice_abstract_v002_train2015_questions.json')
#train_questions_file = os.path.join(data_path)
train_questions_feature = 'questions'
train_questions = load_data(train_questions_file, train_questions_feature )




# Define the annotations file
train_annotations_file = os.path.join(data_path, 'train2015/abstract_v002_train2015_annotations.json')
train_annotations_feature = 'annotations'
train_annotations = load_data(train_annotations_file, train_annotations_feature)



# Define the annotations file
train_captions_file = os.path.join(data_path, 'train2015/captions_abstract_v002_train2015.json')
train_captions_feature = 'images'
train_captions = load_data(train_captions_file, train_captions_feature)



# Define the annotations file
train_OpenEnded_file = os.path.join(data_path, 'train2015/OpenEnded_abstract_v002_train2015_questions.json')
train_OpenEnded_feature = 'questions'
train_OpenEnded = load_data(train_OpenEnded_file, train_OpenEnded_feature)
# Out:
# File found: /content/drive/My Drive/Colab Notebooks/train2015/MultipleChoice_abstract_v002_train2015_questions.json
# Data loaded successfully
# File found: /content/drive/My Drive/Colab Notebooks/train2015/abstract_v002_train2015_annotations.json
# Data loaded successfully
# File found: /content/drive/My Drive/Colab Notebooks/train2015/captions_abstract_v002_train2015.json
# Data loaded successfully
# File found: /content/drive/My Drive/Colab Notebooks/train2015/OpenEnded_abstract_v002_train2015_questions.json
# Data loaded successfully

# %% [markdown]
# 2.2 MERGE TRAIN DATA

# %%
# Merge questions and answers

#train_data = pd.merge(train_questions, train_annotations, on='question_id')
train_data = pd.merge(train_questions, train_annotations, on=["image_id", "question_id"])

df_train = train_data.merge(train_captions, on='image_id')
df_train.head(5)
# Out:
#    image_id                     question  \
# 0     11779           Who looks happier?
# 1     11779  Where is the woman sitting?
# 2     11779    Where is the man sitting?
# 3      5536          Is this man hungry?
# 4      5536  What kind of drink is that?
#
#                                     multiple_choices  question_id  \
# 0  [alive, 1, woman, purple, 2, yes, white, boy, ...       117792
# 1  [3, no, blue, red, 1, slide, monkey bars, jump...       117790
# 2  [away, yes, blue, 1, 2, mouse, couch, no, yell...       117791
# 3  [water, yellow, 4, running, blue, pouring, out...        55360
# 4  [wine, girl would fall, soda, white, yes, coke...        55361
#
#   question_type multiple_choice_answer  \
# 0           who                    man
# 1  where is the                blanket
# 2  where is the                  bench
# 3       is this                    yes
# 4  what kind of                   soda
#
#                                              answers answer_type  \
# 0  [{'answer': 'old person', 'answer_confidence':...       other
# 1  [{'answer': 'on blanket', 'answer_confidence':...       other
# 2  [{'answer': 'on bench', 'answer_confidence': '...       other
# 3  [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 4  [{'answer': 'water', 'answer_confidence': 'no'...       other
#
#                                                  url  \
# 0  http://visualqa.org/data/abstract_v002/scene_i...
# 1  http://visualqa.org/data/abstract_v002/scene_i...
# 2  http://visualqa.org/data/abstract_v002/scene_i...
# 3  http://visualqa.org/data/abstract_v002/scene_i...
# 4  http://visualqa.org/data/abstract_v002/scene_i...
#
#                                   file_name  width  height
# 0  abstract_v002_train2015_000000011779.png    700     400
# 1  abstract_v002_train2015_000000011779.png    700     400
# 2  abstract_v002_train2015_000000011779.png    700     400
# 3  abstract_v002_train2015_000000005536.png    700     400
# 4  abstract_v002_train2015_000000005536.png    700     400

# %% [markdown]
# # STEP 3 : EDA

# %% [markdown]
# From the above examples, we can see that most of the questions and answers are simple and clean text but some questions contain punctuation, common word contractions like what’s, it’s, they’re, etc, and noun contractions like guy’s, man’s, dog’s, etc., and some answers also contain punctuation. Hence, we need to perform the data cleaning operation on the question and answer dataset and expand contractions before performing EDA.

# %%
def decontractions(phrase):
    """decontracted takes text and convert contractions into natural form.
     ref: https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python/47091490#47091490"""
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"won\’t", "will not", phrase)
    phrase = re.sub(r"can\’t", "can not", phrase)

    phrase = re.sub(r"he\'s", "he is", phrase)
    phrase = re.sub(r"she\'s", "she is", phrase)
    phrase = re.sub(r"it\'s", "it is", phrase)

    phrase = re.sub(r"he\’s", "he is", phrase)
    phrase = re.sub(r"she\’s", "she is", phrase)
    phrase = re.sub(r"it\’s", "it is", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)

    phrase = re.sub(r"n\’t", " not", phrase)
    phrase = re.sub(r"\’re", " are", phrase)
    phrase = re.sub(r"\’d", " would", phrase)
    phrase = re.sub(r"\’ll", " will", phrase)
    phrase = re.sub(r"\’t", " not", phrase)
    phrase = re.sub(r"\’ve", " have", phrase)
    phrase = re.sub(r"\’m", " am", phrase)

    return phrase


def text_preprocess(text):
    text = text.lower()
    text = decontractions(text) # replace contractions into natural form
    text = re.sub('[-,:]', ' ', text) # replace the character "-" "," with space
    text = re.sub("(?!<=\d)(\.)(?!\d)", '', text) # remove the character ".", except from floating numbers
    text = re.sub('[^A-Za-z0-9. ]+', '', text) # remove all punctuation, except A-Za-z0-9
    text = re.sub(' +', ' ', text) # remove extra space
    return text

# Question and Answer text preprocessing
df_train["question_preprocessed"] = df_train["question"].map(lambda x: text_preprocess(x))
df_train["answer_preprocessed"] = df_train["multiple_choice_answer"].map(lambda x: text_preprocess(x))

# %%
df_train.head(3)
# Out:
#    image_id                     question  \
# 0     11779           Who looks happier?
# 1     11779  Where is the woman sitting?
# 2     11779    Where is the man sitting?
#
#                                     multiple_choices  question_id  \
# 0  [alive, 1, woman, purple, 2, yes, white, boy, ...       117792
# 1  [3, no, blue, red, 1, slide, monkey bars, jump...       117790
# 2  [away, yes, blue, 1, 2, mouse, couch, no, yell...       117791
#
#   question_type multiple_choice_answer  \
# 0           who                    man
# 1  where is the                blanket
# 2  where is the                  bench
#
#                                              answers answer_type  \
# 0  [{'answer': 'old person', 'answer_confidence':...       other
# 1  [{'answer': 'on blanket', 'answer_confidence':...       other
# 2  [{'answer': 'on bench', 'answer_confidence': '...       other
#
#                                                  url  \
# 0  http://visualqa.org/data/abstract_v002/scene_i...
# 1  http://visualqa.org/data/abstract_v002/scene_i...
# 2  http://visualqa.org/data/abstract_v002/scene_i...
#
#                                   file_name  width  height  \
# 0  abstract_v002_train2015_000000011779.png    700     400
# 1  abstract_v002_train2015_000000011779.png    700     400
# 2  abstract_v002_train2015_000000011779.png    700     400
#
#         question_preprocessed answer_preprocessed
# 0           who looks happier                 man
# 1  where is the woman sitting             blanket
# 2    where is the man sitting               bench

# %% [markdown]
# # STEP 4 : Preprocess the Image--CNN

# %% [markdown]
# 4.1. Encoding image size (batch size, channel, height, weight)

# %%
preprocess = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

# 2. 加载图像并进行预处理
def load_images_from_folder(folder_path):
    images = []
    count_id = []
    for filename in os.listdir(folder_path): #get image from googledrive
     if filename in df_sample_5k["file_name"].values:
       #only choose 5k sample from googledrive that match selected dataframe
        if filename.endswith('.png'):  # only load PNG image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path).convert('RGB')  # open and convert to  RGB
            image_tensor = preprocess(image)  # preprocssing as  Tensor
            images.append(image_tensor)
            count_id.append(filename.split('.')[0])
    return  torch.stack(images)  # 将所有 Tensor 拼接成一个批处理 (batch) 的 Tensor

# %% [markdown]
# 4.2 Create CNN model and output as fully connected Layer (batch size, channel* height * weight)

# %%
# Step 2: CNN Model After Image Encoding
class CNNAfterEncoding(nn.Module):
    def __init__(self):
        super(CNNAfterEncoding, self).__init__()
        # Encoder (ResNet50)
         # First Conv Layer: 3 input channels (RGB), 16 output channels, 3x3 kernel size
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)

        # Second Conv Layer: 16 input channels, 32 output channels, 3x3 kernel size
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)

        # Max Pool Layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Fully Connected (hidden) layer: Flatten the input to fit the fully connected layer
        self.fc1 = nn.Linear(32 * 56 * 56, 128)  # 32 filters, 56x56 feature map size after pooling twice

        # Output layer: 128 input features, 10 output classes (example for classification)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        # Pass through first Conv layer followed by ReLU and Max Pooling
        x = self.pool(F.relu(self.conv1(x)))  # Output: (batch_size, 16, 112, 112)

        # Pass through second Conv layer followed by ReLU and Max Pooling
        x = self.pool(F.relu(self.conv2(x)))  # Output: (batch_size, 32, 56, 56)

        # Flatten the tensor for the fully connected layer
        x = x.view(-1, 32 * 56 * 56)  # Flatten to shape (batch_size, 32 * 56 * 56)

        # Pass through the fully connected hidden layer
        x = F.relu(self.fc1(x))  # Output: (batch_size, 128)

        # # Pass through the final output layer
        # x = self.fc2(x)  # Output: (batch_size, 10) - logits for 10 classes ...we dont need output for CNN

        return x

# %% [markdown]
# # STEP 5 : Preprocessing the Question --RNN

# %%
# 将问题文本转换为索引
def text_to_indices(df):
      all_questions = " ".join(df).split()
      unique_words = list(set(all_questions))
      word_to_index = {word: index for index, word in enumerate(unique_words)}
      vocab_size = len(word_to_index)  # 词汇表大小
      return [word_to_index[word] for word in all_questions if word in word_to_index]



max_length = 10# 填充索引以使其具有相同的长度（假设最大长度为10）

# question encoder
def question_encoder(text,max_length):
  questions_indices = [text_to_indices(question) for question in text ]
  questions_indices_padded = [q + [0] * (max_length - len(q)) if len(q) < max_length else q[:max_length] for q in questions_indices]
  questions_tensor = torch.tensor(questions_indices_padded, dtype=torch.long)# 将问题索引转换为 Tensor
  return questions_tensor





# 定义 QuestionEncoder 类
class QuestionEncoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, num_layers):
        super(QuestionEncoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)

    def forward(self, question):
        embedded = self.embedding(question)
        _, (hidden, _) = self.lstm(embedded)
        return hidden[-1]  # 返回最后一层的隐藏状态

# %% [markdown]
# # STEP 6 : Answer Encoder

# %%
# answers = df_sample_5k["answer_preprocessed"]

# # Step 2: Create a vocabulary of all unique words
# vocab = {word: idx for idx, word in enumerate(set(answers))}
# print("Vocabulary:", vocab)

# # Example Output: {'blue': 0, 'yes': 1, 'no': 2, 'maybe': 3, 'red': 4, 'definitely': 5, 'sometimes': 6, 'green': 7}

# # Step 3: Convert each answer into its corresponding index
# answer_indices = [torch.tensor([vocab[word]]) for word in answers]
# print("Answer Indices (before batching):", answer_indices)

# # Example Output: [tensor([1]), tensor([2]), tensor([3]), tensor([5]), tensor([1]), tensor([2]), ...]

# # Step 4: Pad the sequences to ensure they have the same length
# # Since these are single words, padding is not needed. But if the answers are sequences of different lengths:
# encoded_answers_tensor = torch.tensor(answer_indices)
# print(f"Encoded answers tensor: {encoded_answers_tensor.shape}")


def answer_encoder(answers):
       vocab = {word: idx for idx, word in enumerate(set(answers))}
       answer_indices = [torch.tensor([vocab[word]]) for word in answers]
       encoded_answers_tensor = torch.tensor(answer_indices)
       return encoded_answers_tensor

# %% [markdown]
# #step 7 :  Build VQA model

# %%
# VQA model: Combine image and question features and predict the answer
class VQAModel(nn.Module):
    def __init__(self, image_feat_size, question_feat_size, hidden_size, answer_vocab_size):
        super(VQAModel, self).__init__()
        self.fc1 = nn.Linear(image_feat_size + question_feat_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, answer_vocab_size)

    def forward(self, image_features, question_features):
        combined_features = torch.cat((image_features, question_features), dim=1) # COMBINE image fully connected layer and RNN fully connected layer
        x = torch.relu(self.fc1(combined_features))
        x = self.fc2(x)
        return x

# %% [markdown]
# # 7. VQA model

# %%
# Example usage
def main():
    # Hyperparameters
    vocab_size = 1000  # Example vocab size (should be equal to the number of unique tokens in your question dataset)
    embed_size = 300
    hidden_size = 512
    num_layers = 1
    answer_vocab_size = 100  # Example number of possible answers


    #question_encoder = QuestionEncoder(vocab_size, embed_size, hidden_size, num_layers)
    vqa_model = VQAModel(image_feat_size=128, question_feat_size=64, hidden_size=512, answer_vocab_size=answer_vocab_size)

    #flattened_image_features = image_batch.view(batch_size, -1)
    # Predict the answer
    result = vqa_model(output, question_features)
    print("Model output (answer logits):", result.shape) #18,100

    # You would typically apply a softmax here to get answer probabilities
    predicted_answer = torch.argmax(result, dim=1)
    print("Predicted answer index:", predicted_answer)



    # Use CrossEntropyLoss to compare logits and ground truth answers
    criterion = nn.CrossEntropyLoss()
    loss = criterion(result, encoded_answers_tensor)
    print(f"Loss: {loss.item()}")
    return loss.item()

# %% [markdown]
# # STEP 8 : loop 5 times

# %%
n_iterations = 100
final_loss_result=[]
for i in range(n_iterations):
    print(f"Running model iteration {i + 1}")
    # get random 50 data
    batch_size=50
    df_sample_5k = df_train.sample(n=batch_size, replace=True, random_state=42)



    # 模型参数
    embed_size = 128     # 嵌入维度
    hidden_size = 64     # LSTM 隐藏层维度
    num_layers = 2       # LSTM 层数
    vocab_size = 100 #len(word_to_index)  # 词汇表大小
   # question feature , image feature and answer encoder
    image_batch = load_images_from_folder(extract_dir_test)
    model = CNNAfterEncoding()
    output = model(image_batch)#final fully connected layer output


    questions_tensor=question_encoder(df_sample_5k["question_preprocessed"],max_length = 10)
    model = QuestionEncoder(vocab_size, embed_size, hidden_size, num_layers)
    question_features = model(questions_tensor)# 前向传播，获取问题特征
    print(question_features.shape)


    encoded_answers_tensor=answer_encoder(df_sample_5k["answer_preprocessed"])

    main()
    lossitem=main()
    final_loss_result.append(lossitem)
# Out:
# Running model iteration 1
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([78, 78, 34, 34, 78, 34, 78, 34, 78, 34, 34, 34, 34, 78, 34, 34, 34, 78,
#         78, 78, 61, 78, 34, 34, 34, 78, 78, 78, 34, 34, 34, 34, 78, 34, 78, 78,
#         34, 78, 34, 78, 78, 78, 34, 34, 34, 78, 34, 34, 34, 78])
# Loss: 4.595491886138916
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([92, 70, 92, 92, 92, 92, 53, 92, 92, 92, 70, 92, 92, 92, 92, 92, 92, 92,
#         48, 92, 92, 92, 92, 92, 92, 92, 92, 92, 70, 92, 53, 92, 92, 70, 53, 92,
#         92, 92, 70, 92, 92, 92, 70, 70, 70, 70, 92, 92, 92, 92])
# Loss: 4.623171806335449
# Running model iteration 2
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([77, 77, 77, 77, 23, 77, 77, 77, 77, 23, 77, 77, 77, 77, 77, 77, 77, 77,
#         62, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 28,
#         77, 77, 77, 77, 77, 77, 23, 77, 77, 77, 23, 77, 77, 77])
# Loss: 4.612391471862793
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([88, 28,  9, 28, 23, 23, 28, 28, 28, 28, 28, 28, 28, 88, 28, 28, 28, 28,
#         28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28,
#         28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 20, 28, 28, 28])
# Loss: 4.5902886390686035
# Running model iteration 3
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([48, 81,  7, 81, 77,  7,  7,  7, 81, 81, 91, 81, 81,  7,  7, 81, 81,  7,
#         81, 81,  7,  7,  7,  7, 81,  7,  7, 81, 81,  7, 91,  0,  7, 81, 81, 81,
#         57, 81, 81, 81,  7,  7, 81, 81, 81, 81, 81, 81, 48, 81])
# Loss: 4.615368843078613
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76,
#         76, 76, 11, 76, 76, 76, 76, 76, 76, 11, 76, 76, 76, 76, 76, 76, 76, 11,
#         76, 76, 76, 76, 76, 76, 76, 76, 11, 76, 76, 76, 76, 76])
# Loss: 4.594942092895508
# Running model iteration 4
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([26, 43,  4, 43,  4,  4, 26, 43, 43, 43,  4, 26, 43, 26, 26, 43, 98, 26,
#         43, 43, 43, 96,  4, 43, 43,  4, 43, 43, 43, 26, 26, 26, 26, 43, 43, 43,
#         80, 43, 43, 98, 26, 26, 43, 43, 98, 43, 43,  4, 26, 98])
# Loss: 4.6167988777160645
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40,  8, 40, 40,  8,  8, 40,
#          8, 40, 40, 40, 40, 40, 40, 40, 40, 59, 40, 40, 40, 40, 40,  8, 40, 40,
#         40, 72, 40, 40,  8, 40, 40, 40, 40, 40, 40, 40, 40, 40])
# Loss: 4.585247039794922
# Running model iteration 5
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([49, 49, 49, 23, 49, 49, 49, 23, 49, 23, 49, 23, 49, 49, 49, 49, 49, 49,
#         49, 23, 49, 49, 49, 49, 58, 49, 49, 49, 31, 49, 49, 49, 23, 23, 49, 23,
#         49, 49, 49, 49, 49, 49, 49, 23, 49, 23, 23, 49, 49, 23])
# Loss: 4.605899333953857
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 3,  0,  3, 21, 21, 21,  7,  0,  3,  0, 21, 64, 64,  3,  3, 21,  0,  3,
#         21,  3, 21,  3,  7,  7, 64,  3,  3, 64,  0, 64, 64,  3, 21, 21,  0, 64,
#          3,  0, 64,  3,  3,  3,  0,  0, 21,  3,  3, 64,  3, 64])
# Loss: 4.599073886871338
# Running model iteration 6
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 73, 58, 58, 58, 58, 58, 58, 58,
#         58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58,
#         58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 50, 58])
# Loss: 4.610649585723877
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([24, 48, 48,  9, 53,  9, 48, 48,  9, 48, 24,  9,  9, 48, 48, 48, 48,  9,
#         24, 24,  9, 53, 48, 48, 53, 48, 48, 24, 48,  9, 24, 24,  9, 48, 24, 48,
#         24, 24, 24, 24,  9, 53,  9, 24, 24,  9, 53, 48, 24,  9])
# Loss: 4.610198497772217
# Running model iteration 7
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([57, 57, 57, 57, 57, 26, 21, 21, 57, 57, 57, 57, 57, 57, 53, 57, 57, 21,
#         57, 57, 53, 57, 57, 21, 21, 57, 57, 57, 57, 21, 57, 57, 21, 53, 57, 57,
#         57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57, 57])
# Loss: 4.591226577758789
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([78, 14, 70, 14, 63, 34, 34, 14, 88, 34, 47, 34, 14, 29, 34, 88, 63, 31,
#         88, 14, 84, 97, 70, 12, 47, 14, 47, 70, 88, 34, 31, 31, 34, 70, 34, 14,
#         70, 14, 14, 14, 31, 29, 47, 14, 84, 47, 34, 47, 84, 14])
# Loss: 4.596617221832275
# Running model iteration 8
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([31, 31, 31, 31, 31, 42, 31, 31, 42, 42, 31, 31, 31, 31, 31, 31, 31, 31,
#         31, 42, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
#         31, 31, 31, 31, 31, 31, 31, 31, 42, 31, 31, 31, 31, 31])
# Loss: 4.618401050567627
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([53, 25, 25, 53, 53, 53, 53, 25, 25, 53, 25, 53, 53, 53, 25, 53, 25, 25,
#         53, 53, 53, 53, 25, 53, 53, 25, 25, 53, 25, 53, 53, 53, 25, 53, 25, 53,
#         88, 82, 25, 25, 53, 53, 53, 53, 25, 53, 53, 53, 53, 25])
# Loss: 4.604278087615967
# Running model iteration 9
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([52, 22, 49, 48, 22, 71, 22, 48, 48, 49, 71, 48, 52, 52, 48, 71, 48, 52,
#         71, 71, 71, 49, 22, 71, 49, 48, 52, 71, 49, 48, 71, 52, 48, 48, 48, 71,
#         52, 22, 48, 71, 52, 52, 52, 48, 48, 48, 49, 71, 52, 48])
# Loss: 4.6037983894348145
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([46, 50, 65, 92, 13, 50, 13, 80, 13, 92, 92, 65, 44, 13, 52, 13, 50, 50,
#         50, 80, 50, 65, 65, 50, 92, 50, 13, 13, 92, 65, 65, 50, 92, 50, 92, 50,
#         13, 13, 50, 13, 65, 80, 44, 13, 65, 46, 50, 13, 40, 52])
# Loss: 4.626816272735596
# Running model iteration 10
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([93, 29, 93, 29, 29, 29, 93, 18, 42, 55, 93, 93, 42, 29, 42, 84, 43, 29,
#         42, 47, 29, 29, 29, 93, 93, 29, 93, 29, 29, 93, 93, 42, 42, 93, 29, 42,
#         93, 43, 29, 29, 93, 93, 43, 29, 42, 29,  5, 93, 93, 93])
# Loss: 4.609437942504883
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([77, 14, 77, 14, 77,  0, 99, 99,  0, 77, 99, 77, 14, 99,  0,  0, 14, 99,
#          0,  0,  0, 99, 77, 99, 77, 77, 64, 99, 77, 99, 99,  0, 77,  0,  0,  0,
#         99, 14, 14, 99,  0, 77, 14,  0, 14, 14,  0, 61, 14, 11])
# Loss: 4.588082790374756
# Running model iteration 11
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([80, 50, 50, 50, 50, 74, 74, 50, 50, 50, 80, 50, 50, 80, 80, 80, 24, 50,
#         74, 50, 50, 50, 69, 50, 74, 74, 50, 50, 50, 50, 50, 22, 50, 74, 50, 50,
#         22, 50, 50, 80, 50, 50, 99, 74, 24, 69, 74, 50, 50, 50])
# Loss: 4.621902942657471
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([26, 26, 18, 61, 26, 18, 18, 18, 64, 26, 26, 61, 61, 26, 18, 18, 61, 18,
#         18, 61, 18, 18,  8, 61, 61, 18, 18, 18, 18, 26, 26, 26, 18, 61, 26, 18,
#         26, 18, 18, 18, 18, 18, 26, 61, 61, 61, 18, 26, 18, 61])
# Loss: 4.596673488616943
# Running model iteration 12
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([47, 62, 62, 62, 47, 62, 62, 47, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62,
#         47, 62, 62, 62, 62, 62, 62, 62, 62, 47, 62, 62, 62, 62, 47, 62, 62, 62,
#         62, 47, 62, 47, 62, 62, 62, 47, 62, 62, 62, 62, 62, 62])
# Loss: 4.609515190124512
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([54, 58, 54, 54, 54, 54, 54, 62, 54, 62, 54, 62, 54, 54, 62, 54, 54, 11,
#         62, 54, 62, 54, 54, 62, 62, 54, 54, 54, 62, 62, 54, 34, 62, 34, 62, 29,
#         54, 54, 54, 54, 62, 62, 62, 29, 54, 62, 54, 54, 62, 54])
# Loss: 4.6085028648376465
# Running model iteration 13
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 6, 26,  6, 27,  6,  6,  6,  6, 66, 26,  6, 66, 66,  6,  6, 88, 26,  6,
#          6, 26,  6,  6,  6,  6, 26,  6,  6, 50, 27,  6,  6,  6,  6,  6, 66, 26,
#          6, 61, 26,  6,  6,  6, 61, 26, 26,  6,  6,  6,  6,  6])
# Loss: 4.613849639892578
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([57, 57, 72, 57, 57, 57, 57, 57, 57, 57, 57, 29, 58, 58, 72, 57, 57, 13,
#         40, 57, 57, 29, 57, 57, 57, 13, 57, 57, 57, 29, 29, 57, 72, 57, 57, 57,
#         57, 29, 57, 57, 76, 57, 57, 57, 57, 58, 57, 57, 57, 57])
# Loss: 4.61721658706665
# Running model iteration 14
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([86, 86, 36, 46, 66, 63, 36, 36, 86,  0, 79, 86,  0, 36, 63, 36,  0, 94,
#          0,  0, 94, 86, 86, 86, 63, 36,  0, 86,  0,  0, 86, 53, 63,  0, 63,  0,
#         36,  0, 86, 86, 86, 86,  0, 64,  0, 36, 86,  0, 86, 53])
# Loss: 4.587843894958496
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([28, 28, 28, 28, 28, 25, 28, 25, 28, 28, 28, 28, 28, 28, 28, 25, 28, 28,
#         28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 25, 28, 28, 28, 28, 28, 28, 28,
#         28, 25, 25, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28])
# Loss: 4.617790699005127
# Running model iteration 15
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([41, 55, 41, 41, 41, 68, 55, 41, 41, 41, 27, 41,  5, 41, 41, 73, 41, 55,
#         41, 27, 27, 55, 55, 85, 41, 41, 41, 41, 41, 27, 55, 55, 41, 41, 55, 41,
#         27,  4, 41, 41, 55, 41, 41, 68, 41, 41, 58, 27, 41, 41])
# Loss: 4.611264228820801
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([37, 37, 34, 34, 14, 43, 37, 98, 37, 34, 37, 63, 34, 34, 14, 37, 34, 37,
#         34, 14, 14, 37, 37, 14, 34, 34, 14, 14, 34, 34, 14, 37, 34, 34, 34, 34,
#         14, 34, 34, 34, 34, 34, 34, 34, 37, 34, 34, 34, 37, 34])
# Loss: 4.597343921661377
# Running model iteration 16
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([27, 77, 61, 66,  6, 77,  6, 35, 35, 35, 50, 50, 77, 50, 27, 92, 35, 61,
#         77, 35, 77, 77, 66, 77, 35, 77,  6, 61, 35, 61, 35, 50, 50, 77, 77, 77,
#          6, 77, 77, 50, 61, 61, 35, 61, 77, 35, 66, 50, 61, 61])
# Loss: 4.615553855895996
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([94, 61, 94, 64, 64, 94, 94, 64, 94, 60, 94, 18, 61, 94, 18, 64, 94, 94,
#         60, 94, 51, 94, 94, 94, 60, 18, 18, 94, 18, 94, 64, 18, 94, 18, 94, 60,
#         94, 64, 18, 94, 94, 18, 94, 18, 94, 61, 18, 94, 18, 64])
# Loss: 4.617160797119141
# Running model iteration 17
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 5,  5,  5, 60,  5,  5,  5, 25, 60, 25, 60,  5,  5,  5,  5,  5, 60,  5,
#          5,  5, 60,  5, 10,  5, 60,  5,  5,  5,  5, 15,  5,  5,  5,  5, 60, 60,
#          5, 60, 60, 60,  5,  5, 60, 60, 60, 60,  5,  5,  5,  5])
# Loss: 4.587064743041992
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([52, 73, 73, 89,  4,  4, 52, 73, 73,  7, 52, 13, 52, 89, 52, 13, 57, 52,
#          4, 13, 52, 73, 73, 89, 89, 89, 57, 57, 73,  4,  4, 57, 52, 52, 89, 73,
#         52, 13, 13,  4,  4, 52, 57, 13,  4, 13, 13, 73, 73, 73])
# Loss: 4.602418422698975
# Running model iteration 18
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([46, 46, 37, 13, 46, 46, 46, 13, 46, 13, 46, 13, 46, 46, 13, 46, 46, 46,
#         46, 46, 46, 46, 46, 46, 37, 99, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46,
#         46, 46, 46, 37, 46, 46, 46, 13, 46, 46, 58, 46, 46, 46])
# Loss: 4.625710964202881
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([27, 27, 52, 52, 52, 27, 27, 52, 27, 25, 27, 52, 27, 27, 27, 27, 52, 52,
#         27, 27, 27, 27, 27, 27, 27, 27, 27, 52, 52, 52, 27, 52, 27, 10, 27, 62,
#         27, 52, 27, 27, 52, 27, 27, 27, 62, 52, 62, 27, 52, 62])
# Loss: 4.602686882019043
# Running model iteration 19
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([99, 70, 99, 51, 99, 29,  2,  6, 70, 99, 11, 99,  6, 99, 99, 99, 51,  2,
#          6,  6, 29, 94, 94, 94, 11,  2, 29, 94, 99, 99, 99, 94, 29, 51, 99,  6,
#          2, 99, 99, 94, 29,  2, 99,  6, 99,  6, 70, 94, 29, 99])
# Loss: 4.5981268882751465
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([73, 73, 73, 73, 51, 51, 73, 25, 73, 51, 73, 73, 25, 73, 73, 73, 73, 73,
#         51, 51, 73, 73, 73, 73, 51, 73, 73, 73, 73, 73, 51, 73, 73, 41, 25, 43,
#         73, 73, 51, 73, 73, 73, 51, 73, 73, 73, 41, 51, 73, 73])
# Loss: 4.6152262687683105
# Running model iteration 20
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([68, 68, 68, 68, 68, 68, 68, 13, 68, 68, 68, 68, 68, 68, 68, 25, 13, 68,
#         77, 25, 13, 68, 68, 68, 50, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 13,
#         13, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68])
# Loss: 4.614466190338135
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 9, 58, 25, 58, 55, 23, 58, 84, 84,  9,  9, 84, 66,  9,  9, 84,  9, 58,
#         23, 84,  9, 25,  9, 25, 84,  9,  9, 25, 55, 58, 23, 23, 23, 23, 25, 84,
#         58, 84,  9,  9, 96, 25, 25, 84,  9, 84,  9,  9, 25,  9])
# Loss: 4.604844093322754
# Running model iteration 21
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([67, 67, 67, 67, 67, 67, 67,  4, 67, 67, 67, 28, 94, 67, 67, 67, 67, 67,
#         67,  4, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67,
#         67, 67, 67, 67, 67, 67, 28, 28, 67, 67, 67, 67, 67, 67])
# Loss: 4.598313331604004
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([70, 86, 73, 70,  9, 86, 86, 86, 86, 94, 86, 86, 86, 86, 86, 86, 86,  9,
#         86, 86, 24, 86,  9, 86, 86, 86, 86, 86, 86, 24, 86, 86, 73, 86, 86, 86,
#         86, 86, 86, 94, 70, 86, 86, 86, 86, 86, 86, 86, 70, 86])
# Loss: 4.59103536605835
# Running model iteration 22
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([73, 73, 73, 73, 73, 73, 73, 84, 73, 73, 73, 73, 80, 73, 73, 73, 73, 73,
#         73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 80, 73, 73, 73, 73, 73, 73, 73,
#         73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 59, 73, 73, 73])
# Loss: 4.6156110763549805
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([44, 22, 44, 44,  6, 44, 69, 44, 63, 44, 44, 44, 44, 44, 44, 63, 63, 44,
#         20, 44, 63, 63, 85, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44,
#         85, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 63])
# Loss: 4.6030497550964355
# Running model iteration 23
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([19,  9, 28, 89, 34, 73,  9, 89,  9, 89, 75, 89, 75, 19, 28,  9, 89,  9,
#         19, 63, 34, 13, 34, 19, 13, 19, 19, 34, 89, 34, 28, 34, 28, 73, 89,  9,
#          9, 73, 89, 28, 34, 28, 34, 73,  9, 19,  9, 19, 19, 13])
# Loss: 4.615784168243408
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([47, 44, 53, 47, 89, 49, 44, 44, 44, 39, 34, 44, 44, 47, 34, 44, 49, 44,
#         44, 44, 44, 44, 44, 39, 47, 44, 44, 47, 49, 89, 39, 39, 44, 44, 49, 44,
#         44, 44, 34, 44, 47, 47, 49, 49, 28, 47, 44, 47, 47, 44])
# Loss: 4.611746311187744
# Running model iteration 24
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 7,  7,  7,  7, 76,  7, 88, 88, 88,  7, 76,  7,  3, 88, 76, 76,  7, 88,
#          7,  7, 88, 88, 88, 88,  7, 88, 88,  7,  7, 76, 76, 76,  7,  3,  7,  7,
#          7,  7,  3,  7, 88, 88,  7,  7,  7,  7,  7,  7,  7,  7])
# Loss: 4.626126766204834
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([84, 84, 79, 84, 28, 79, 79, 84, 28, 29, 28, 85, 79, 28, 79, 28, 28, 84,
#         84, 84, 28, 79, 28, 84, 79, 79, 84, 79, 28, 28, 79, 28, 79, 79, 79, 84,
#         28, 79, 84, 85, 84, 28, 28, 85, 84, 79, 79, 84, 84, 28])
# Loss: 4.606923580169678
# Running model iteration 25
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 4,  4, 74,  4,  4, 74,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4, 74,
#          4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4, 74,  4,  4,  4,
#          4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4])
# Loss: 4.620355606079102
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([16, 43, 16, 40, 72, 16, 16, 24, 43, 45, 16, 45, 24, 16, 16, 16, 73, 16,
#         72, 24, 16, 16, 16, 16, 73, 16, 16, 16, 45, 16, 16, 16, 16, 73, 16, 24,
#         16, 88, 16, 16, 16, 16, 56, 73, 73, 40, 56, 16, 73, 72])
# Loss: 4.6339311599731445
# Running model iteration 26
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([14, 71,  9, 71,  9,  9, 71, 71, 71, 71, 71, 14, 14,  9, 14, 14, 71, 14,
#         71, 14, 14, 71, 71, 14, 14, 71,  9,  9, 71,  9, 71, 48,  9, 71,  9, 71,
#         71, 71, 14, 71, 14,  9, 71, 71, 71, 14, 14, 14, 14, 71])
# Loss: 4.586101055145264
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([53, 36,  3, 67, 67, 67, 91, 36, 67, 67, 67, 67, 67, 28, 67, 91, 67, 53,
#         67, 36, 91, 28, 53, 91, 67,  3, 67, 91, 67, 91, 91, 91, 67, 67, 67, 91,
#         91, 91, 67, 91, 53, 91, 36, 67, 67, 67, 36, 28, 91, 67])
# Loss: 4.609769821166992
# Running model iteration 27
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([38, 83, 38, 67, 37, 37, 18, 38, 83, 44, 83, 38, 38, 37, 38, 44, 44, 37,
#         18, 44, 83, 67, 38, 67, 44, 37, 18, 83, 44, 37, 18, 67, 18, 18, 18, 18,
#         38, 44, 44,  7, 38, 83, 23, 18, 18, 44, 38, 38, 38, 83])
# Loss: 4.5935235023498535
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([45, 68, 45, 45, 45, 45, 45, 68, 56, 45, 45, 45, 68, 45, 45, 12, 65, 45,
#         68, 47, 45, 68, 45, 45, 45, 45, 45, 45, 47, 45, 45, 45, 45, 45, 45, 36,
#         45, 47, 68, 45, 45, 45, 68, 47, 45, 36, 47, 45, 45, 47])
# Loss: 4.603113174438477
# Running model iteration 28
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([74, 91, 91, 91, 91, 86, 91, 28, 91, 91, 91, 91, 91, 91, 91, 91, 91, 56,
#         29, 91, 86, 91, 91, 91, 91, 91, 91, 67, 91, 66, 91, 91, 91, 91, 91, 48,
#         91, 91, 91, 91, 91, 91, 91, 91, 91, 86, 86, 91, 91, 91])
# Loss: 4.602360248565674
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 2,  2,  2,  2,  2,  2,  2, 27,  2, 27, 33,  2,  2,  2,  2, 27, 27,  2,
#          2, 27,  2,  2,  2,  2, 27, 33,  2, 33, 33,  2,  2,  2,  2,  2,  2, 27,
#          2, 27, 27,  2,  2,  2, 63, 63, 27, 63, 74,  2,  2, 27])
# Loss: 4.608302116394043
# Running model iteration 29
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([64, 64, 64, 64, 64, 64, 64, 64, 64,  8, 64, 50, 64, 64, 64, 64,  8, 64,
#         64, 64, 64, 64, 64, 64, 64, 64, 64, 64,  8, 64, 64, 64, 64, 64, 64, 64,
#         64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64])
# Loss: 4.588080883026123
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([40, 94, 94, 94, 40, 40, 94, 94, 29, 94, 94, 94, 94, 40, 40, 94, 29, 40,
#         29, 94, 94, 94, 40, 12, 12, 12, 40, 40, 94, 94, 40, 94, 94, 94, 94, 94,
#         29, 94, 29, 40, 80, 80, 88, 80, 40, 94, 29, 12, 40, 94])
# Loss: 4.593052387237549
# Running model iteration 30
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([73, 73, 48, 71, 94, 71, 48, 48, 73, 48, 98, 98, 96, 48, 73, 71, 73, 98,
#         96, 83, 83, 94, 98, 48, 73, 98, 98, 83, 73, 48, 73, 98, 98, 48, 96, 71,
#         71, 83, 73, 24, 98, 98, 71, 71, 71,  6, 71, 48, 98, 73])
# Loss: 4.596446514129639
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 8,  8,  4, 55,  8,  8,  4,  4, 55, 44,  4,  4, 75,  4, 40,  4, 75,  8,
#         75,  4, 75,  8,  8,  4, 55,  8,  8,  4,  8,  4,  4, 75, 75, 75, 75, 75,
#          4, 66, 55,  8,  4,  8, 75, 75, 75, 55, 55,  8,  8, 75])
# Loss: 4.595600605010986
# Running model iteration 31
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([67, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 69, 67, 67, 69, 67, 69,
#         67, 69, 67, 67, 69, 67, 67, 69, 67, 69, 69, 31, 67, 69, 69, 67, 69, 69,
#         69, 69, 69, 69, 69, 67, 69, 67, 18, 69, 69, 67, 67,  3])
# Loss: 4.595905780792236
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79,  3, 79, 79, 79, 79, 79, 79,
#         79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79,
#         79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79])
# Loss: 4.592813491821289
# Running model iteration 32
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([47, 47, 47, 47, 47, 51, 51, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 51,
#         47, 47, 51, 47, 47, 47, 47, 47, 47, 47, 47, 51, 47, 47, 47, 47, 51, 47,
#         47, 51, 47, 47, 51, 47, 47, 47, 47, 47, 47, 47, 47, 47])
# Loss: 4.611653804779053
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([39, 39, 86, 40, 39, 80, 40, 39, 39, 39, 86, 39, 39, 40, 40, 40, 34, 86,
#         86, 40, 40, 86, 86, 86, 40, 10, 86, 40, 75, 10, 10, 40, 86, 40, 86, 40,
#         86, 39, 39, 86, 40, 40, 86, 86, 40, 86, 86, 40, 10, 86])
# Loss: 4.607970714569092
# Running model iteration 33
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([68, 25, 88, 88, 25, 68, 25, 88, 88, 25, 25, 25, 25, 25, 88, 25, 88, 25,
#         25, 25, 88, 25, 25, 25, 38, 88, 25, 25, 25, 25, 25, 68, 25, 25, 88, 25,
#         25, 25, 25, 88, 25, 25, 25, 25, 25, 25, 25, 25, 25, 88])
# Loss: 4.59981107711792
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([69, 69, 73, 73, 73, 73, 73, 69, 69, 69, 73, 73, 69, 73, 73, 69, 69, 51,
#         73, 69, 73, 73, 73, 73, 73, 73, 73, 73, 69, 73, 73, 73, 73, 73, 73, 69,
#         73, 69, 69, 73, 73, 69, 73, 91, 69, 73, 69, 73, 69, 69])
# Loss: 4.608695030212402
# Running model iteration 34
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73,
#         73, 73, 73, 73, 73,  6, 73, 67, 73, 73, 73, 73, 13, 73, 73, 73, 73, 73,
#         73, 73, 73, 73,  6, 73, 73, 73, 73, 73, 73, 73, 73, 73])
# Loss: 4.598050117492676
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#         35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#         35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35])
# Loss: 4.589547157287598
# Running model iteration 35
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([15, 15, 16, 15, 15, 15, 15,  6, 44, 15, 44, 74, 15, 15,  6, 44, 16, 16,
#         44, 83, 98, 98, 16,  6,  6, 15, 15, 44, 16, 16, 15, 15,  6,  6, 83, 44,
#         15, 74, 15, 44, 44, 15, 16, 16, 44, 16, 15, 98, 15, 16])
# Loss: 4.603431224822998
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([47, 47, 47, 47, 47, 80, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47,
#         47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47,
#         47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47])
# Loss: 4.617379665374756
# Running model iteration 36
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([88, 86, 86, 86, 88, 88, 86, 86, 86, 88, 86, 86, 88, 86, 88,  1, 86, 86,
#         88, 86, 86, 86, 86, 86, 86, 86, 77, 86, 86, 86, 77, 88, 86, 88,  1, 86,
#         88, 88, 86, 86, 86, 88, 86, 88, 86,  1, 86, 86, 86, 86])
# Loss: 4.61505126953125
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 0, 90, 90, 90,  0, 90, 90,  0, 90, 90, 90,  0, 90, 90, 90,  6,  0,  0,
#          0,  6,  0, 90, 90, 90, 90, 90, 90, 90,  0, 90, 90, 90, 90,  0,  0,  0,
#         90,  0, 90, 25,  0, 90,  6, 90, 90,  6, 90, 90, 90, 90])
# Loss: 4.599857330322266
# Running model iteration 37
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([27, 27, 42, 27, 27, 27, 27,  0, 27, 42, 27, 42, 27, 42, 42, 27, 42, 27,
#         42, 42, 27, 27, 27, 42, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27,  0, 27,
#         27, 27, 27, 27, 27, 42, 27, 27, 27, 27, 27, 42, 27,  0])
# Loss: 4.606717109680176
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([91, 51, 91,  3, 91,  3, 91, 93, 42,  3, 91,  3, 42, 44, 91, 51,  3, 91,
#         34,  3,  3,  3, 44,  3,  3, 51, 91, 91,  3, 44,  3,  3, 42,  3,  3, 51,
#          3,  3, 42, 91,  3, 42,  3, 91,  3, 51,  3, 42,  3,  3])
# Loss: 4.610780715942383
# Running model iteration 38
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([25, 25, 25, 25, 25, 25, 25, 25, 25, 60, 60, 25, 25, 74, 25, 25, 25, 25,
#         25, 25, 25, 32, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 60, 25,
#         25, 25, 60, 74, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25])
# Loss: 4.5826215744018555
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([28, 28, 59, 28,  2, 74, 12, 28, 12, 28, 28, 28, 28, 28, 60, 28, 59, 28,
#         28, 28, 28, 28, 28,  2, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28,
#         28, 28, 28,  2, 74, 28, 28, 28, 28, 28, 28, 12, 28, 54])
# Loss: 4.603164196014404
# Running model iteration 39
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([43, 35, 84, 43, 87, 87, 87, 76, 87, 35, 87, 84, 35, 87, 43, 87, 84, 87,
#         43, 43, 87, 87, 87, 87, 76, 87, 43, 43, 35, 87, 87, 84, 43, 87, 87, 43,
#         43, 35, 35, 87, 43, 43, 43, 87, 84, 35, 43, 84, 43, 76])
# Loss: 4.609490394592285
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([77, 36, 36, 77, 36, 36, 77, 77, 77, 77, 77, 77, 77, 36, 36, 36, 77, 77,
#         77, 36, 77, 36, 77, 77, 77, 77, 77, 36, 36, 77, 36, 77, 77, 77, 77, 36,
#         36, 36, 47, 77, 77, 77, 92, 77, 77, 36, 47, 77, 77, 77])
# Loss: 4.6117024421691895
# Running model iteration 40
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([89, 73,  4,  4,  4,  7,  4, 73,  4, 89, 14, 89, 89, 73, 89, 89,  4,  7,
#         89, 24, 73, 73, 73,  4, 89, 73, 89, 51, 26, 73, 73,  7, 73,  4, 73, 89,
#         14, 73, 26, 73,  4,  4, 89,  7, 89, 73,  4,  4,  4, 26])
# Loss: 4.598977565765381
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([32, 32, 32, 32, 32, 14, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32])
# Loss: 4.610938549041748
# Running model iteration 41
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([53, 53, 53, 29, 29, 53, 36, 53, 53, 53, 53,  5, 53, 53, 53, 29, 29, 36,
#         53, 29, 36, 53, 53, 53, 29, 53, 36, 53,  5, 53, 53, 29, 36, 29, 53, 29,
#         53, 29, 29, 53, 29, 36, 29, 29, 53, 29, 29, 53, 53, 29])
# Loss: 4.619025707244873
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 7, 75, 11, 53, 76, 36, 18, 75, 18, 75, 18, 18, 18,  7, 55, 18, 76,  7,
#         75, 18,  7, 11, 14, 76, 76, 42, 42, 94, 18, 55, 67, 11, 18, 75, 75, 75,
#         42, 11, 76, 18,  7,  7, 75, 76, 18, 75, 18,  7, 33, 11])
# Loss: 4.6018147468566895
# Running model iteration 42
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([49, 91, 49, 18, 91, 91, 49, 91, 91, 91, 91, 49, 49, 49, 91, 91, 91, 91,
#         91, 49, 49, 49, 91, 49, 91, 49, 91, 13, 91, 91, 91, 91, 91, 91, 91, 91,
#         49, 91, 43, 18, 49, 91, 91, 91, 49, 49, 91, 49, 91, 49])
# Loss: 4.605087757110596
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([94, 94, 94, 94, 94, 94, 94, 41, 41, 94, 94, 94, 94, 94, 94, 41, 94, 94,
#         94, 42, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 42, 94, 42, 41,
#         94, 94, 42, 94, 94, 94, 94, 94, 41, 42, 42, 94, 94, 94])
# Loss: 4.6150617599487305
# Running model iteration 43
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 79,
#         79, 79, 79, 79, 79, 79, 79, 79, 79, 79, 61, 79, 79, 79, 79, 79, 79, 79,
#         79, 79, 79, 79, 79, 79, 79, 14, 79, 79, 79, 79, 79, 79])
# Loss: 4.594180107116699
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([63, 72, 63, 72, 72, 63, 72, 72, 72, 72, 72, 72, 72, 72, 68, 72, 72, 72,
#         72, 72, 85, 72,  6, 72, 72, 72, 72, 72, 72, 72, 72, 72, 63, 72, 72, 72,
#         72, 18, 43, 63, 72, 72, 72, 72, 72, 72, 72, 63, 72, 72])
# Loss: 4.590724468231201
# Running model iteration 44
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([51, 55, 36, 55, 79, 11, 51, 40, 51, 79, 51, 55, 79, 55, 51, 79, 79, 79,
#         55, 79, 51, 51, 51, 51, 79, 51, 36, 55, 79, 51, 36, 48, 73, 79, 55, 55,
#         11, 79, 79, 51, 11, 36, 79, 55, 55, 55, 79, 51, 36, 55])
# Loss: 4.606300354003906
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([11, 42, 54, 11, 11, 11, 11, 11, 11, 11, 11, 54, 42, 42, 54, 11, 11, 11,
#         11, 11, 54, 80, 42, 54, 42, 42, 11, 11, 11, 42, 54, 54, 42, 27, 11, 11,
#         11, 11, 11, 11, 11, 54, 11, 11, 11, 11, 11, 54, 11, 42])
# Loss: 4.611996173858643
# Running model iteration 45
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#         3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#         3, 3])
# Loss: 4.595579147338867
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([69, 69, 69, 69, 69, 69, 69, 67, 69, 69, 69, 92, 51, 69, 54, 94, 94, 69,
#         69, 69, 69, 69, 69, 69, 94, 69, 69, 95, 69, 94, 69,  1, 95, 69, 69, 69,
#         69, 69, 69, 69, 69, 67, 24, 69, 69, 51, 51, 94, 69, 94])
# Loss: 4.608470916748047
# Running model iteration 46
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([74, 12, 12, 46, 74, 34, 12, 46, 12, 74, 14, 12, 34, 74, 74, 34, 74, 74,
#         34, 74, 74, 74, 12, 74, 74, 74, 12, 12, 74, 74, 12, 44, 12, 74, 74, 74,
#         74, 46, 34, 44, 12, 12, 74, 74, 74, 34, 34, 12, 74, 74])
# Loss: 4.588966369628906
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([60,  8, 36, 60, 60, 36, 36, 60, 48, 36, 60, 60, 48, 60, 60, 34, 34, 60,
#         34, 60, 36, 36, 60, 36, 48, 36, 36, 36, 36, 60, 60, 60, 60, 60, 34, 34,
#         60, 36, 34, 48, 60, 55, 36, 36, 36, 34, 27, 36, 60, 70])
# Loss: 4.612954616546631
# Running model iteration 47
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([75, 75, 55, 24, 75, 35, 55, 35, 75, 24, 15, 24, 55, 55, 24, 65, 75, 75,
#         75, 24, 75, 55, 24, 35, 60, 75, 65, 35, 75, 75, 75, 75, 75, 24, 75, 34,
#         35, 75, 35, 75, 75, 75, 75, 75, 75, 75, 60, 15, 75, 75])
# Loss: 4.5959367752075195
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([93, 52, 52, 97, 52, 93, 52, 52, 52,  4, 52, 93, 52, 52, 52, 93,  4, 52,
#         52, 38, 52, 52, 52, 93, 52, 52, 52, 93, 93, 20, 93, 52, 97, 52, 97, 52,
#         52, 52, 52, 52, 93, 52, 52, 95, 95, 93, 38, 85, 93, 52])
# Loss: 4.586445331573486
# Running model iteration 48
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([55, 94, 55, 94, 64, 55, 94, 55, 94, 94, 55, 94, 94, 94, 64, 94, 94, 55,
#         64, 55, 55, 55, 94, 55, 94, 94, 55, 55, 94, 94, 94, 55, 34, 64, 94, 94,
#         64, 64, 64, 94, 94, 55, 94, 94, 94, 55, 55, 94, 94, 94])
# Loss: 4.591814994812012
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([56,  7, 56,  7,  7,  7,  7,  7,  7,  7, 86,  7,  7,  7,  7,  7,  7,  7,
#          7, 56, 19,  7,  7,  7,  7, 86,  7, 86, 33,  7,  7, 56,  7,  7, 19,  7,
#          7,  7, 86,  7, 56, 42,  7,  7,  7, 19, 86, 56, 33,  7])
# Loss: 4.611871719360352
# Running model iteration 49
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([18, 95, 38, 18, 18, 38, 18, 38, 95, 18, 38, 38, 95, 18, 38, 18, 38, 38,
#         18, 95, 18, 38, 18, 18, 38, 85, 18, 18, 38, 38, 18, 38, 47, 95, 38, 95,
#         38, 38, 38, 18, 38, 18, 38, 38, 21, 95, 38, 47, 38, 38])
# Loss: 4.60310173034668
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([75, 75, 55, 55, 75, 75, 75, 75, 75, 75, 90, 75, 90, 75, 75, 75, 90, 75,
#         55, 75, 75, 90, 75, 75, 10, 55, 90, 75, 75, 75, 75, 75, 75, 75, 75, 75,
#         75, 75, 75, 75, 75, 55, 75, 90, 75, 75, 75, 55, 75, 75])
# Loss: 4.596163749694824
# Running model iteration 50
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([66, 54, 54, 20, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 66, 54, 54, 54,
#         66, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 53, 66, 54, 54, 54,
#         54, 54, 20, 54, 66, 54, 54, 54, 54, 54, 54, 54, 54, 54])
# Loss: 4.584912300109863
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([89, 89, 89, 89, 89, 89, 89, 42, 89, 89, 89, 89, 89, 89, 89, 42, 89, 89,
#         89, 89, 89,  4, 80, 80, 42, 80, 89, 89, 42, 89, 89, 89, 89,  4, 47, 42,
#         89, 89, 42, 89, 89,  4, 42, 42, 42, 89, 80, 80, 89, 89])
# Loss: 4.603382110595703
# Running model iteration 51
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([29, 73, 29, 53, 29, 29, 29, 53, 73, 53, 91, 29, 29, 29, 29, 73, 73, 29,
#         73, 73, 91, 29, 29, 91, 53, 29, 29, 96, 73, 29, 29, 53, 29, 53, 73, 73,
#         73, 73, 73, 29, 29, 29, 53, 96, 73, 53, 91, 29, 29, 73])
# Loss: 4.613828182220459
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([95, 87, 95, 87, 18, 47, 95, 18, 87, 87, 95, 18, 47, 95, 87, 18, 87, 95,
#         18, 18, 95, 95, 95, 87, 87, 95, 95, 95, 18, 18, 95, 95, 95, 47, 18, 18,
#         87, 18, 87, 87, 18, 95, 47, 18, 18, 18, 95, 95, 95, 87])
# Loss: 4.603940010070801
# Running model iteration 52
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([52, 67, 72, 20, 52, 52, 52, 73, 67, 52, 52, 67, 67, 52, 52, 52, 20, 72,
#         20, 67, 52, 72, 67, 52, 52, 72, 67, 72, 67, 72, 67, 52, 72, 72, 16, 67,
#         52, 52, 20, 72, 52, 52, 67, 67, 67, 52, 67, 16, 52, 67])
# Loss: 4.5825676918029785
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([56,  7,  7,  7, 92, 92, 70, 40, 39, 70, 56,  7, 40, 40,  7, 70, 70, 56,
#          7, 70, 39,  7, 61, 75,  7, 56, 61, 61, 70, 61, 40, 92, 70, 56,  7,  7,
#          7, 56, 40, 40, 61,  7, 70, 56, 70, 70,  7, 70, 70,  7])
# Loss: 4.613825798034668
# Running model iteration 53
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([39, 39, 39, 72, 39, 84, 84, 39, 39, 57, 39, 39, 39, 39, 39, 39, 39, 84,
#         39, 57, 39, 39, 39, 84, 39, 84, 39, 39, 84, 39, 39, 39, 39, 39, 22, 25,
#         39, 25, 39, 39, 39, 39, 57, 39, 25, 72, 39, 84, 84, 39])
# Loss: 4.60496711730957
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([80, 98, 68, 98, 73, 95, 95, 98, 98, 98, 95, 73, 98, 98, 98, 66, 98, 98,
#         98, 66, 95, 68, 98, 68, 80, 80, 98,  1, 80, 95, 66, 68, 98, 35, 98, 80,
#         10, 80, 80, 98, 66, 68, 80, 98, 80, 98, 80, 98, 95, 98])
# Loss: 4.6255574226379395
# Running model iteration 54
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([15, 49, 49, 49, 49, 49, 49, 17, 69, 69, 72, 49, 15, 49, 49, 69, 72, 49,
#         49, 15, 15, 49, 49, 49, 49, 49, 49, 49, 69, 49, 49, 49, 49, 49, 15, 69,
#         49, 69, 69, 49, 92, 49, 69, 49, 49, 69, 15, 49, 49, 15])
# Loss: 4.598989486694336
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([73, 60, 73, 73, 75, 61, 73, 73, 60, 60, 73, 73, 73, 73, 73, 60, 60, 61,
#         73, 73, 61, 73, 73, 61, 60, 73, 73, 73, 60, 73, 73, 73, 75, 45, 73, 60,
#         73, 60, 60, 73, 73, 73, 73, 73, 73, 60, 60, 73, 73, 73])
# Loss: 4.622833728790283
# Running model iteration 55
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([64, 40, 71, 40, 47, 40, 85, 40, 40, 40, 64, 44, 40, 40, 40, 64, 40, 44,
#         40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 35, 40, 64, 40, 40, 40, 13, 40,
#         40, 40, 40, 40, 64, 40, 13, 40, 85, 13, 64, 40, 64, 40])
# Loss: 4.617974758148193
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 4, 34,  4, 34,  4,  4, 34, 34, 34, 34,  4, 34, 34, 42, 42,  4,  4, 42,
#          4, 34, 34,  4, 34, 73, 34, 34, 42, 47, 34,  4,  4, 42,  4, 34, 34, 34,
#          4, 34, 34, 34,  4, 34, 34, 34, 34, 34, 34, 42,  4, 42])
# Loss: 4.622520923614502
# Running model iteration 56
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58,
#         91, 58, 58, 26, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58,
#         58, 58, 91, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58])
# Loss: 4.601015090942383
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([20, 66, 20, 20, 20, 66, 20, 20, 66, 65, 20, 20, 20, 20, 20, 20, 20, 20,
#         20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 66, 20, 20, 20, 20, 20, 65, 66,
#         20, 66, 20, 20, 20, 20, 20, 20, 20, 20, 66, 20, 20, 20])
# Loss: 4.566734313964844
# Running model iteration 57
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 3,  3,  3, 42,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, 42,  3, 94,  3,
#          3,  3,  3,  3,  3,  3, 94,  3,  3,  3,  3, 42,  3,  3,  3, 42,  3,  3,
#          3,  3, 94,  3,  3,  3,  3, 94,  3,  3,  3,  3,  3,  3])
# Loss: 4.6323723793029785
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 2, 37, 57, 37, 57, 31,  2, 37, 31, 37, 31, 31, 31,  2, 31, 31, 37, 31,
#         31,  2, 31,  2, 31, 31, 37, 31, 31, 31,  2,  2, 31, 31,  2, 90, 37,  2,
#         31,  2, 31, 31, 31,  2, 93, 31, 31, 37, 37,  2, 57,  2])
# Loss: 4.596158504486084
# Running model iteration 58
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([89, 89, 89, 89, 70, 89, 70, 70, 70, 70, 70, 70, 89, 89, 70, 32, 70, 89,
#         70, 70, 70, 70, 70, 70, 89, 62, 70, 89, 89, 89, 70, 70, 89, 70, 70, 62,
#         70, 70, 89, 70, 70, 89, 70, 70, 70, 89, 62, 70, 70, 70])
# Loss: 4.604307651519775
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([11, 12, 12, 12, 12, 12, 12, 36, 36, 12, 12, 12, 12, 12, 12, 36, 36, 12,
#         12, 36, 12, 12, 12, 12, 12, 36, 12, 11, 36, 12, 12, 36, 12, 12, 12, 12,
#         12, 12, 36, 12, 17, 12, 36, 12, 12, 36, 36, 17, 82, 12])
# Loss: 4.5708909034729
# Running model iteration 59
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([78, 78, 78, 78, 78, 82, 78, 78, 78, 82, 78, 78, 82, 78, 78, 82, 78, 78,
#         82, 82, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 73,
#         73, 82, 78, 78, 73, 78, 78, 78, 78, 78, 78, 78, 78, 78])
# Loss: 4.603103160858154
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([56,  1,  1, 16, 67, 33,  9, 56,  1,  1,  1, 67,  1,  1, 67,  1, 33, 67,
#          1,  1, 67, 56, 67,  1, 16, 67,  1,  9, 56,  1,  1, 84,  9, 13, 56,  1,
#         67,  1,  1,  9, 56,  9, 56, 16, 16,  1, 67,  1,  1, 33])
# Loss: 4.61042594909668
# Running model iteration 60
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([30, 30, 30, 84, 30, 30, 30, 84, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#         30, 84, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 84, 30,
#         30, 84, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30])
# Loss: 4.6146931648254395
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63,
#         63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63,
#         63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63])
# Loss: 4.606118679046631
# Running model iteration 61
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([77, 77, 77, 46, 77, 77, 77, 57, 77, 46, 77, 77, 77, 77, 46, 77, 77, 50,
#         77, 77, 77, 77, 77, 77, 95, 77, 77, 77, 77, 77, 77, 48, 77, 77, 77, 82,
#         46, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77, 77])
# Loss: 4.598555564880371
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([58, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 94, 58,
#         58, 58, 94, 94, 58, 94, 94, 25, 94, 58, 94, 94, 94, 94, 94, 23, 58, 94,
#         94, 25, 94, 94, 58, 94, 94, 94, 58, 94, 94, 94, 94, 94])
# Loss: 4.59397029876709
# Running model iteration 62
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([52, 72, 52, 52, 72, 72, 60, 52, 72, 72, 72, 72, 60, 52, 52, 72, 54, 60,
#         72, 72, 52, 52, 52, 52, 72, 52, 52, 52, 72, 52, 52, 72, 52, 52, 72, 52,
#         52, 72, 72,  7, 47, 52, 72, 72, 54, 72, 72, 52, 52, 72])
# Loss: 4.62207555770874
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([74, 47, 47,  9, 47, 47, 69, 69, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47,
#         47, 47, 47, 47, 47, 47, 47, 69, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47,
#         47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47])
# Loss: 4.641777515411377
# Running model iteration 63
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([40, 97,  1, 26, 40, 40, 40,  1, 40, 26, 40, 97, 97, 40, 40, 26, 26, 40,
#         46, 26, 40,  1, 40, 40, 40, 40,  1, 40, 97, 46, 46, 48, 40, 40, 97, 26,
#          1,  1, 48, 40, 40, 40, 46, 97, 97, 46, 26,  1, 40, 40])
# Loss: 4.610026836395264
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([68, 71, 68, 71, 80, 68, 71, 80, 68, 71, 80, 71, 80, 80, 68, 71, 68, 71,
#         68, 80, 68, 68, 80, 80, 71, 71, 80, 68, 71, 80, 68, 71, 68, 71, 68, 71,
#         68, 71, 71, 68, 71, 68, 68, 71, 71, 71, 80, 68, 68, 71])
# Loss: 4.609541416168213
# Running model iteration 64
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([84, 37, 37, 37, 37, 84, 37, 57, 37, 37, 37, 57, 56, 37, 37, 68, 37, 37,
#         56, 37, 37, 56, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 84, 37, 37, 57,
#         37, 37, 57, 37, 37, 84, 37, 37, 37, 84, 37, 37, 37, 56])
# Loss: 4.61060905456543
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([57, 16, 57, 16, 57, 57, 16, 38, 16, 16, 16, 16, 57, 57, 57, 16, 16, 57,
#         16, 16, 16, 16, 57, 57, 16, 16, 16, 16, 16, 57, 57, 16, 57, 16, 57, 16,
#         16, 63, 63, 57, 16, 57, 16, 16, 16, 16, 16, 16, 16, 16])
# Loss: 4.580955982208252
# Running model iteration 65
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([84, 84, 34, 23, 26, 34, 26, 40, 84, 26, 40, 84,  9, 26, 84, 23, 84, 34,
#         34, 26, 34, 84, 23, 34, 62, 84, 34, 40, 84, 26, 84, 84, 34,  9, 23, 34,
#         84, 26, 34, 34, 34, 34, 40, 23, 26, 26, 34, 26, 34, 34])
# Loss: 4.5989766120910645
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([40, 34, 40, 40, 34, 34, 40, 40, 40, 40, 40, 70, 40, 40, 34, 70, 34, 34,
#         40, 40, 34, 34, 40, 34, 40, 40, 40, 34, 34, 40, 40, 34, 34, 40, 34, 40,
#         34, 40, 40, 40, 40, 40, 34, 34, 34, 40, 40, 40, 40, 40])
# Loss: 4.608114242553711
# Running model iteration 66
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([84, 98, 84, 44, 84, 84, 33, 84, 98, 84, 84, 84, 84, 33, 33, 84, 98, 84,
#         84, 84, 98, 84, 33,  9, 33, 84, 84, 84, 84, 33, 33, 33, 81, 84, 33, 44,
#         84, 44, 84, 81, 33, 84, 84,  9, 84, 84, 84,  9,  9, 98])
# Loss: 4.610133171081543
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([18, 73, 73, 73,  5, 73,  5, 73, 73, 73, 18, 18, 73, 73, 73, 73, 73, 68,
#         96, 73,  5, 18, 18,  5, 73, 18, 18,  5, 73, 18,  5,  5, 18, 73,  7, 96,
#         18, 15, 73, 18, 18, 68, 73, 73, 73, 96, 18,  5,  5, 73])
# Loss: 4.629845142364502
# Running model iteration 67
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([55, 55, 55, 55,  8, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55,  8, 16,
#         16, 55, 66, 55, 55, 55,  8, 16,  8, 55, 16, 16,  8, 55, 55, 16, 55, 16,
#         55, 55, 55, 55, 66, 55, 16, 16, 16, 16, 55, 55, 55, 16])
# Loss: 4.613192081451416
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([53, 53, 60, 60, 60, 53, 60, 53, 60, 60, 53, 53, 60, 25, 60, 60, 53, 53,
#         53, 86, 60, 25, 53, 53, 60, 53, 91, 53, 25, 53, 53, 53, 60, 60, 85, 53,
#         53, 53, 53, 60, 61, 91, 60, 86, 53, 53, 91, 91, 60, 53])
# Loss: 4.623215675354004
# Running model iteration 68
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([18, 23, 68, 18, 17, 18, 18, 18, 36, 91, 68, 52, 52, 18, 18, 61, 36, 18,
#         36, 61, 91, 68, 18, 18, 18, 18, 18, 18, 36, 36, 18, 27, 18, 18, 18, 36,
#         18, 36, 61, 18, 95, 68, 23, 27, 27, 68, 27, 18, 18, 27])
# Loss: 4.598907947540283
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([54, 95, 43, 52, 53, 43, 53, 43, 43, 95, 43, 53, 95, 53, 53, 54, 43, 43,
#         43, 54, 54, 43, 53, 95, 95, 53, 53, 24, 43, 43, 43, 43, 53, 95, 53, 53,
#         53, 54, 95, 53, 53, 43, 43, 43, 43, 53, 53, 53, 53, 43])
# Loss: 4.593560695648193
# Running model iteration 69
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 7,  7,  7,  7, 36,  7,  7,  7,  7,  7,  7, 36, 36,  7,  7,  7,  7,  7,
#          7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7, 36,  7,  7,
#          7,  7,  7,  7,  7,  7,  7,  7,  7, 36,  7,  7,  7,  7])
# Loss: 4.598176956176758
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58, 58,
# ...
# Predicted answer index: tensor([57, 29, 28, 26, 71, 71,  8, 22, 26, 26, 72, 29, 22, 26, 29, 29, 26, 71,
#         65, 26, 57, 22, 28, 26, 29, 57, 55, 72, 26, 28, 72, 71, 29, 26, 29, 72,
#         55, 29, 28, 71, 57, 71, 72, 72, 29, 29, 29, 71, 29, 26])
# Loss: 4.612946033477783
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 5,  5,  5, 59, 59, 59,  5,  5, 59, 59,  5, 59, 59,  5,  5, 59, 59, 59,
#          5,  5,  5, 59,  5, 59, 59,  5,  5,  5, 59, 59,  5,  5,  5, 59, 59,  5,
#          5,  5, 59, 59,  5, 59, 59, 59, 59, 59,  5,  5,  5, 59])
# Loss: 4.602806568145752
# Running model iteration 79
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([55, 39, 30, 30, 55, 93, 30, 51, 73, 30, 51, 30, 94, 12, 94, 51, 51, 12,
#         73, 51, 12, 30, 12, 94, 30, 55, 94, 83, 51, 94, 94, 51, 12, 51, 12, 93,
#         94, 51, 51, 30, 12, 12, 39, 39, 51, 30, 73, 30, 55, 51])
# Loss: 4.5947723388671875
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([65, 65, 65, 65, 65, 65, 83, 65, 65, 65, 83, 65, 65, 83, 65, 65, 65, 65,
#         65, 65, 83, 65, 65, 65, 65, 65, 65, 65, 65, 83, 83, 65, 65, 65, 65, 65,
#         65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 83, 65])
# Loss: 4.6008782386779785
# Running model iteration 80
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([12,  0,  0,  0, 12, 24, 65, 65,  0, 65, 65,  0, 65, 65,  0,  0, 65, 22,
#         51, 65, 24, 22, 65, 65, 65, 12,  0, 65,  0,  0, 65, 24, 88, 65, 65, 65,
#         24,  0, 51,  0, 65, 12, 65, 65, 34, 65,  0, 88, 24, 65])
# Loss: 4.581523895263672
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 8, 59, 59, 98, 31, 98, 59, 59, 59, 59,  8, 59,  8, 59, 59, 59, 59,  3,
#         92, 59,  3, 31, 96, 59, 47, 59,  8,  8, 59,  8, 47, 31,  8,  8, 59, 92,
#         31,  8, 59, 59,  8,  3, 47, 31, 59, 91, 92, 31, 59, 59])
# Loss: 4.596318244934082
# Running model iteration 81
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 6,  6,  6,  6,  0,  6,  6,  6,  6,  6,  6,  6,  6,  6, 56,  6,  6,  6,
#          6,  6,  6,  6, 56,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,
#          6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6])
# Loss: 4.594345569610596
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([91, 82, 49, 43, 49, 40, 49, 72, 43, 43, 49, 43, 91, 43, 43, 43, 49, 49,
#         82, 82, 43, 49, 49, 43, 43, 49, 43, 92, 43, 49, 43, 49, 49, 82, 91, 43,
#         92, 49, 54, 49, 49, 49, 43, 43, 43, 49, 43, 49, 49, 43])
# Loss: 4.606074333190918
# Running model iteration 82
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([17, 17, 46, 46, 17, 17, 17, 17, 17, 17, 17, 17, 17, 46, 17, 17, 17, 46,
#         46, 17, 17, 46, 46, 17, 46, 46, 17, 46, 46, 17, 17, 17, 17, 46, 46, 17,
#         46, 17, 46, 17, 17, 17, 17, 46, 46, 17, 17, 46, 46, 46])
# Loss: 4.59990119934082
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([72, 72, 72, 66, 72, 66, 72, 12, 72, 72, 72, 66, 66, 66, 72, 66, 72, 66,
#         66, 66, 66, 72, 50, 72, 66, 72, 72, 72, 72, 72, 72, 72, 72, 66, 66, 66,
#         72, 72, 66, 66, 66, 72, 66, 66, 72, 66, 72, 66, 72, 72])
# Loss: 4.601595401763916
# Running model iteration 83
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([60, 60, 21, 60, 21, 21, 60, 60, 60, 60, 70, 60, 60, 60, 60, 60, 60, 60,
#         60, 60, 21, 60, 70, 21, 60, 60, 60, 60, 60, 21, 60, 21, 21, 60, 33, 60,
#         21, 60, 28, 60, 60, 70, 33, 60, 60, 60, 60, 60, 70, 60])
# Loss: 4.592502593994141
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([20, 20, 20, 20, 74, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20,
#         20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20,
#         74, 64, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20])
# Loss: 4.575771808624268
# Running model iteration 84
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([57, 36, 57, 36, 57, 31, 57, 36, 47, 57, 57, 80, 65, 57, 31, 57, 57, 31,
#         57, 65, 31, 57, 57, 57, 57, 57, 36, 31, 36, 57, 57, 36, 57, 69, 36, 65,
#         31, 65, 31, 36, 31, 31, 36, 65, 31, 65, 57, 57, 57, 31])
# Loss: 4.581790924072266
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([33, 76, 33, 76, 77, 99, 33, 33, 68, 33, 33, 68, 76, 77, 77, 77, 33, 77,
#         77, 68, 77, 33, 77, 33, 33, 77, 33, 99, 33, 68, 34, 77, 33, 77, 99, 76,
#         77, 33, 76, 77, 77, 14, 34, 33, 68, 77, 31, 33, 99, 33])
# Loss: 4.607809066772461
# Running model iteration 85
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([27, 49, 27, 27, 27, 49, 49, 49, 49, 49, 49, 27, 49, 49, 49, 49, 64, 27,
#         49, 49, 49, 64, 64, 49, 49, 27, 49, 49, 27, 49, 27, 41, 49, 49, 27, 49,
#         49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49])
# Loss: 4.616092205047607
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([64, 49, 64, 64, 45, 45, 64, 53, 64, 53, 53, 59, 64, 64, 64, 49, 53, 64,
#         64, 18, 64, 64, 64, 64, 64, 64, 64, 64, 53, 64, 64, 64, 64, 59, 64, 53,
#         64, 49, 64, 64, 64, 64, 53, 64, 71, 49, 53, 64, 64, 53])
# Loss: 4.616331100463867
# Running model iteration 86
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([75, 75, 75, 83, 75, 75, 75, 65, 75, 75, 75, 75, 83, 75, 75, 94, 46, 83,
#         65, 65, 75, 75, 75, 75, 75, 46, 75, 49, 75, 75, 75, 75, 75, 49, 49, 65,
#         75, 75, 49, 46, 49, 75, 49, 49, 75, 75, 75, 75, 75, 75])
# Loss: 4.618620872497559
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([91,  8,  8,  8,  8, 36, 86,  8,  8,  8, 96,  8, 37,  8,  8, 94,  8,  8,
#          8,  8,  8, 92,  8,  8, 96,  8,  8,  8,  8,  8, 96, 96, 37,  8, 96,  8,
#          8,  8,  8, 37,  8,  8, 92, 92, 96,  8,  8,  8, 96, 96])
# Loss: 4.586491107940674
# Running model iteration 87
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 9, 15,  9, 15,  9,  9,  9,  9, 15, 15,  9, 15,  9,  9,  9, 15, 15,  9,
#          9, 15,  9,  9,  9,  9, 15,  9,  9,  9, 15, 62,  9,  9,  9,  9,  9, 15,
#          9,  9,  9,  9,  9,  9,  9,  9, 15, 15,  9,  9,  9, 15])
# Loss: 4.626934051513672
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([30, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 61, 30, 99, 96, 99, 99, 99,
#         99, 99, 99, 99, 99, 30, 30, 99, 30, 99, 99, 30, 30, 99, 99, 99, 99, 99,
#         61, 61, 30, 30, 99, 99, 99, 99, 99, 30, 99, 30, 99, 99])
# Loss: 4.626871585845947
# Running model iteration 88
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 7,  7, 49,  7, 42, 42, 49,  7,  7,  7, 49,  7,  7,  7, 49,  7,  7,  7,
#          7, 70,  7,  7, 49,  7,  7, 54,  7,  7, 24, 49, 42,  7, 49, 43,  7,  7,
#         54, 43, 42,  7,  7,  7,  7,  7,  7, 43, 49, 49, 49,  7])
# Loss: 4.633550643920898
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([12, 12, 12,  0, 13, 12, 12, 72, 81, 13, 12, 12, 81, 12, 12, 13, 12, 12,
#         12, 81, 13, 12, 13, 12, 13, 12, 12, 12, 84, 12, 12, 12, 12, 12, 12, 12,
#         12, 12, 13, 13, 12, 13, 84, 13, 84, 12, 12, 13, 13, 12])
# Loss: 4.574704647064209
# Running model iteration 89
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([74, 74, 74, 55, 55, 74, 55, 74, 55, 55, 36, 36, 55, 36, 55, 74, 55, 36,
#         55, 74, 36, 79, 36, 36, 55, 79, 74, 36, 74, 36, 79, 34, 74, 74, 55, 74,
#         36, 74, 74, 36, 74, 55, 74, 55, 55, 74, 36, 36, 36, 34])
# Loss: 4.603805065155029
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([36, 36, 36, 36, 96, 96, 96, 96, 96, 36, 96, 96, 36, 36, 36, 96, 96, 96,
#         36, 96, 96, 36, 36, 36, 36, 64, 96, 96, 96, 96, 64, 64, 64, 96, 96, 96,
#         96, 96, 36, 64, 96, 96, 96, 90, 96, 96, 36, 36, 96, 64])
# Loss: 4.6264190673828125
# Running model iteration 90
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 35, 18, 18, 18,
#         18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18,
#         18, 18, 18, 18, 18, 18, 35, 18, 18, 18, 18, 18, 18, 35])
# Loss: 4.593278884887695
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([16, 28, 28, 28, 27, 28, 28, 25, 28, 28, 28, 28, 28, 27, 27, 28, 25, 28,
#         28, 28, 28, 28, 28, 27, 28, 28, 28, 29, 17, 28, 28, 28, 28, 28, 28, 28,
#         28, 28, 28, 28, 27, 28, 17, 28, 28, 28, 28, 28, 28, 28])
# Loss: 4.6225504875183105
# Running model iteration 91
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([31, 31, 31, 31, 31, 74, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
#         31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
#         31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31])
# Loss: 4.5907793045043945
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70,
#         70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70,
#         70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70])
# Loss: 4.591769218444824
# Running model iteration 92
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 5, 29, 29,  5, 29,  5, 29, 29,  5, 54, 29, 29,  5, 29, 54, 54, 29, 29,
#         29, 29, 29, 29, 29, 29, 54, 29, 29, 29, 29,  5, 54, 29,  5, 29, 29, 29,
#         29, 29, 29, 29,  5,  5,  5,  5, 29, 29, 29, 29, 54, 29])
# Loss: 4.6179704666137695
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([69, 24, 69, 24, 69, 69, 49, 24, 24, 19, 69, 16, 19, 69, 69, 19, 19, 49,
#         69, 19, 24, 69, 69, 69, 69, 89, 19, 69, 24, 69, 49, 69, 69, 19, 69, 49,
#         69, 19, 19, 50, 24, 69, 24, 69, 69, 24, 24, 69, 69, 69])
# Loss: 4.592988967895508
# Running model iteration 93
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 3,  3,  3,  3,  3, 46,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#          3,  3, 46,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#          3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3])
# Loss: 4.596776008605957
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([34, 34, 34, 34, 34, 34, 34, 34, 34, 61, 34, 34, 34, 34, 34, 34, 61, 34,
#         34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34,
#         34, 34, 61, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34])
# Loss: 4.591131210327148
# Running model iteration 94
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([78, 60, 81, 48, 48, 45, 48, 48, 60, 48, 45, 48, 60, 45, 48, 60, 48, 60,
#         48, 60, 60, 48, 48, 81, 60, 89, 81, 81, 60, 48, 60, 45, 45, 48, 45, 48,
#         10, 91, 60, 60, 60, 60, 48, 48, 26, 60, 48, 81, 26, 60])
# Loss: 4.62324333190918
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 2,  2, 57, 57, 57, 75, 57, 57, 75, 57, 65, 70, 75, 75, 57, 11, 57, 75,
#         75, 57, 57, 11, 57, 75, 57, 75, 57, 75, 57, 34, 75, 57, 57, 57, 57,  2,
#         11, 57, 75, 75, 30, 75, 57, 57, 34,  2,  2, 57, 57,  2])
# Loss: 4.588963031768799
# Running model iteration 95
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 19,  6, 86, 19, 18, 48, 86, 86,
#         86, 86, 74, 86, 86, 71, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 86,
#         86, 86, 86, 86, 86, 86, 86, 86, 86, 86, 48, 86, 86, 86])
# Loss: 4.589007377624512
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([61, 39, 33, 61, 33, 61, 33, 61, 39, 39, 33, 39, 61, 33, 33, 39, 39, 33,
#         39, 39, 39, 61, 33, 33, 39, 33, 39, 39, 39, 25, 33, 61, 39, 39, 39, 39,
#         39, 39, 33, 33, 33, 61, 39, 61, 39, 33, 39, 39, 39, 39])
# Loss: 4.592432498931885
# Running model iteration 96
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 10, 55, 55, 55, 55, 55,
#         55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55,
#         55, 55, 78, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55, 55])
# Loss: 4.597108840942383
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([60, 60, 30, 60, 22, 60, 60, 60, 18, 60, 30, 60, 60, 60, 60, 60, 30, 60,
#         18, 60, 30, 22, 60, 30, 60,  6, 30, 60, 60, 60, 96,  6, 60, 18, 60, 67,
#         30, 60, 67, 30, 60, 60, 60, 60, 30, 60, 60, 30, 60, 67])
# Loss: 4.600794792175293
# Running model iteration 97
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([82, 40, 40,  1, 40, 40, 40, 11, 82, 11, 40, 82, 11, 82, 40, 11, 11, 40,
#         40, 40, 20, 40, 18, 40, 40, 82, 40, 40,  2, 18, 40, 40, 18, 18, 11, 40,
#         82, 79, 40, 40, 82, 82, 40, 40, 82, 40, 40, 40, 40, 18])
# Loss: 4.579171180725098
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([46, 28, 46, 16, 46, 46, 46, 16, 28, 16, 54, 28, 16, 46, 46, 28, 16, 54,
#         16, 28, 46, 16, 46, 46, 16, 54, 54, 46, 16, 46, 46, 46, 46, 89, 16, 54,
#         46, 16, 16, 46, 46, 46, 28, 16, 28, 28, 28, 46, 46, 16])
# Loss: 4.6198225021362305
# Running model iteration 98
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([13, 13, 13, 13, 13, 13, 13, 36, 13, 36, 13, 13, 13, 13, 13, 13, 36, 13,
#         13, 13, 13, 13, 13, 13, 36, 13, 13, 13, 36, 13, 13, 13, 13, 13, 13, 36,
#         13, 13, 13, 13, 13, 13, 13, 13, 13, 36, 36, 13, 13, 13])
# Loss: 4.613450527191162
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([97, 65, 97, 97, 97,  4, 29, 38, 97, 65, 97, 65, 97, 97, 97, 38, 97, 97,
#         97, 65, 29, 97, 97, 97, 65, 38, 97, 97, 65,  4, 97, 97, 97, 97, 38, 97,
#         97, 65, 38, 97, 29, 29, 65, 97, 65, 65, 97, 97, 97, 65])
# Loss: 4.610898971557617
# Running model iteration 99
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([73, 50, 73, 79, 73, 73, 73, 50, 73, 73, 73, 46, 73, 73, 73, 73, 73, 73,
#         73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 50, 73, 73, 73, 42, 73, 73, 73,
#         73, 50, 50, 73, 73, 73, 73, 73, 73, 73, 50, 73, 73, 73])
# Loss: 4.586629867553711
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62,
#         62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62,
#         62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62])
# Loss: 4.606733798980713
# Running model iteration 100
# torch.Size([50, 64])
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([ 5, 80, 48, 48, 37, 39, 48, 80, 80, 80, 37, 39, 80, 37, 39, 80, 80,  5,
#         80,  7, 37, 48, 37, 37, 80, 37, 48, 48,  5, 80,  5, 80, 80, 80, 80, 80,
#         48, 80, 80, 48, 39, 37, 80, 80, 80, 48, 80, 37, 48, 80])
# Loss: 4.597170352935791
# Model output (answer logits): torch.Size([50, 100])
# Predicted answer index: tensor([16, 68, 16, 68, 16, 99, 68, 68, 68, 68, 16, 68, 68, 68, 16, 16, 68, 68,
#         68, 68, 16, 68, 43, 16, 16, 68, 68, 68, 68, 68, 68, 16, 16, 68, 68, 68,
#         68, 16, 68, 16, 16, 68, 68, 68, 68, 68, 68, 68, 68, 68])
# Loss: 4.596614360809326

# %%
print(f'Average CrossEntropyLoss: ',sum(final_loss_result)/n_iterations)
# Out:
# Average CrossEntropyLoss:  4.603944420814514
