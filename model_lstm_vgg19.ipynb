# %% [markdown]
# <a href="https://colab.research.google.com/github/rllevy/MMAI-Bae/blob/main/model_lstm_vgg19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision transformers
# !pip install tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.19.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)

# %%
# Basic data handling libraries
import pandas as pd
import numpy as np
import os
from os import path
import json
import re
import random
import datetime
import time
import math
import pickle
import joblib
from tqdm import tqdm

# Image processing libraries
from PIL import Image
import cv2
import imgaug.augmenters as iaa

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Machine Learning and Deep Learning libraries
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# TensorFlow and Keras libraries
import tensorflow as tf
from tensorflow import keras
from keras.layers import (Input, Dense, LSTM, Flatten, Dropout, concatenate,
                          Conv1D, MaxPooling2D, Activation, BatchNormalization, Embedding)
from tensorflow.keras import initializers, regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow_hub as hub


from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = '/content/drive/My Drive/Colab Notebooks/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load data
def load_data(data_file, feature):

  # Check if the file exists
  if os.path.exists(data_file):
    print("File found:", data_file)
    with open(data_file, 'r') as f:
        data = json.load(f)
    data = pd.json_normalize(data[feature])
    print("Data loaded successfully")
  else:
    print("File not found:", data_file)

  return data
train_questions_file = os.path.join(data_path, '/content/drive/MyDrive/VQA assignment/MultipleChoice_abstract_v002_train2015_questions.json')
train_questions_feature = 'questions'
train_questions = load_data(train_questions_file, train_questions_feature )


train_annotations_file = os.path.join(data_path, '/content/drive/MyDrive/VQA assignment/abstract_v002_train2015_annotations.json')
train_annotations_feature = 'annotations'
train_annotations = load_data(train_annotations_file, train_annotations_feature)


train_captions_file = os.path.join(data_path, '/content/drive/MyDrive/VQA assignment/captions_abstract_v002_train2015.json')
train_captions_feature = 'images'
train_captions = load_data(train_captions_file, train_captions_feature)

train_OpenEnded_file = os.path.join(data_path, '/content/drive/MyDrive/VQA assignment/OpenEnded_abstract_v002_train2015_questions.json')
train_OpenEnded_feature = 'questions'
train_OpenEnded = load_data(train_OpenEnded_file, train_OpenEnded_feature)
# Out:
# File found: /content/drive/MyDrive/VQA assignment/MultipleChoice_abstract_v002_train2015_questions.json
# Data loaded successfully
# File found: /content/drive/MyDrive/VQA assignment/abstract_v002_train2015_annotations.json
# Data loaded successfully
# File found: /content/drive/MyDrive/VQA assignment/captions_abstract_v002_train2015.json
# Data loaded successfully
# File found: /content/drive/MyDrive/VQA assignment/OpenEnded_abstract_v002_train2015_questions.json
# Data loaded successfully

# %%
#train_data = pd.merge(train_questions, train_annotations, on='question_id')
df_train = pd.merge(train_questions, train_annotations, on=["image_id", "question_id"])

df_train
# Out:
#        image_id                                           question  \
# 0         11779                                 Who looks happier?
# 1         11779                        Where is the woman sitting?
# 2         11779                          Where is the man sitting?
# 3          5536                                Is this man hungry?
# 4          5536                        What kind of drink is that?
# ...         ...                                                ...
# 59995     11695  What color is the log the little girl sitting on?
# 59996     11695             Does the boy want to go on the seesaw?
# 59997     13790                What animal is between the two men?
# 59998     13790                 What food is by the picnic basket?
# 59999     13790                           What is the man holding?
#
#                                         multiple_choices  question_id  \
# 0      [alive, 1, woman, purple, 2, yes, white, boy, ...       117792
# 1      [3, no, blue, red, 1, slide, monkey bars, jump...       117790
# 2      [away, yes, blue, 1, 2, mouse, couch, no, yell...       117791
# 3      [water, yellow, 4, running, blue, pouring, out...        55360
# 4      [wine, girl would fall, soda, white, yes, coke...        55361
# ...                                                  ...          ...
# 59995  [tan, brown, white, 1, running, red, 4, pink, ...       116950
# 59996  [red, no table, fetch, kicking soccer ball, ye...       116951
# 59997  [dog, 4, yellow, 1, collectors, no, red, yes, ...       137900
# 59998  [4, she is happy, grapes, pizza, white, becaus...       137901
# 59999  [blue, cat, yellow, by fire, yes, pouring, roa...       137902
#
#            question_type multiple_choice_answer  \
# 0                    who                    man
# 1           where is the                blanket
# 2           where is the                  bench
# 3                is this                    yes
# 4           what kind of                   soda
# ...                  ...                    ...
# 59995  what color is the                  brown
# 59996           does the                    yes
# 59997     what animal is                    cat
# 59998               what             watermelon
# 59999    what is the man            soccer ball
#
#                                                  answers answer_type
# 0      [{'answer': 'old person', 'answer_confidence':...       other
# 1      [{'answer': 'on blanket', 'answer_confidence':...       other
# 2      [{'answer': 'on bench', 'answer_confidence': '...       other
# 3      [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 4      [{'answer': 'water', 'answer_confidence': 'no'...       other
# ...                                                  ...         ...
# 59995  [{'answer': 'brown', 'answer_confidence': 'yes...       other
# 59996  [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 59997  [{'answer': 'cat', 'answer_confidence': 'yes',...       other
# 59998  [{'answer': 'watermelon, sandwich, burger', 'a...       other
# 59999  [{'answer': 'soccer ball', 'answer_confidence'...       other
#
# [60000 rows x 8 columns]

# %%
mscoco_path = "/content/drive/MyDrive/VQA assignment/scene_img_abstract_v002_train2015"
image_path = list(df_train['image_id'])
question = list(df_train['question'])
answer = list(df_train['multiple_choice_answer'])

# %%
def decontractions(phrase):
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"won\’t", "will not", phrase)
    phrase = re.sub(r"can\’t", "can not", phrase)

    phrase = re.sub(r"he\'s", "he is", phrase)
    phrase = re.sub(r"she\'s", "she is", phrase)
    phrase = re.sub(r"it\'s", "it is", phrase)

    phrase = re.sub(r"he\’s", "he is", phrase)
    phrase = re.sub(r"she\’s", "she is", phrase)
    phrase = re.sub(r"it\’s", "it is", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)

    phrase = re.sub(r"n\’t", " not", phrase)
    phrase = re.sub(r"\’re", " are", phrase)
    phrase = re.sub(r"\’d", " would", phrase)
    phrase = re.sub(r"\’ll", " will", phrase)
    phrase = re.sub(r"\’t", " not", phrase)
    phrase = re.sub(r"\’ve", " have", phrase)
    phrase = re.sub(r"\’m", " am", phrase)

    return phrase


def text_preprocess(text):
    text = text.lower()
    text = decontractions(text) # replace contractions into natural form
    text = re.sub('[-,:]', ' ', text) # replace the character "-" "," with space
    text = re.sub("(?!<=\d)(\.)(?!\d)", '', text) # remove the character ".", except from floating numbers
    text = re.sub('[^A-Za-z0-9. ]+', '', text) # remove all punctuation, except A-Za-z0-9
    text = re.sub(' +', ' ', text) # remove extra space
    return text

def text_preprocess_ans(text):
    text = text.lower()
    text = decontractions(text) # replace contractions into natural form
    text = re.sub('[-,:]', ' ', text) # replace the character "-" "," with space
    text = re.sub("(?!<=\d)(\.)(?!\d)", '', text) # remove the character ".", except from floating numbers
    text = re.sub('[^A-Za-z0-9.! ]+', '', text) # remove all punctuation, except A-Za-z0-9
    text = re.sub(' +', ' ', text) # remove extra space
    return text

# %%
# Question and Answer text preprocessing
df_train["question_preprocessed"] = df_train["question"].map(lambda x: text_preprocess(x))
df_train["answer_preprocessed"] = df_train["multiple_choice_answer"].map(lambda x: text_preprocess_ans(x))

# %%
df_train
# Out:
#        image_id                                           question  \
# 0         11779                                 Who looks happier?
# 1         11779                        Where is the woman sitting?
# 2         11779                          Where is the man sitting?
# 3          5536                                Is this man hungry?
# 4          5536                        What kind of drink is that?
# ...         ...                                                ...
# 59995     11695  What color is the log the little girl sitting on?
# 59996     11695             Does the boy want to go on the seesaw?
# 59997     13790                What animal is between the two men?
# 59998     13790                 What food is by the picnic basket?
# 59999     13790                           What is the man holding?
#
#                                         multiple_choices  question_id  \
# 0      [alive, 1, woman, purple, 2, yes, white, boy, ...       117792
# 1      [3, no, blue, red, 1, slide, monkey bars, jump...       117790
# 2      [away, yes, blue, 1, 2, mouse, couch, no, yell...       117791
# 3      [water, yellow, 4, running, blue, pouring, out...        55360
# 4      [wine, girl would fall, soda, white, yes, coke...        55361
# ...                                                  ...          ...
# 59995  [tan, brown, white, 1, running, red, 4, pink, ...       116950
# 59996  [red, no table, fetch, kicking soccer ball, ye...       116951
# 59997  [dog, 4, yellow, 1, collectors, no, red, yes, ...       137900
# 59998  [4, she is happy, grapes, pizza, white, becaus...       137901
# 59999  [blue, cat, yellow, by fire, yes, pouring, roa...       137902
#
#            question_type multiple_choice_answer  \
# 0                    who                    man
# 1           where is the                blanket
# 2           where is the                  bench
# 3                is this                    yes
# 4           what kind of                   soda
# ...                  ...                    ...
# 59995  what color is the                  brown
# 59996           does the                    yes
# 59997     what animal is                    cat
# 59998               what             watermelon
# 59999    what is the man            soccer ball
#
#                                                  answers answer_type  \
# 0      [{'answer': 'old person', 'answer_confidence':...       other
# 1      [{'answer': 'on blanket', 'answer_confidence':...       other
# 2      [{'answer': 'on bench', 'answer_confidence': '...       other
# 3      [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 4      [{'answer': 'water', 'answer_confidence': 'no'...       other
# ...                                                  ...         ...
# 59995  [{'answer': 'brown', 'answer_confidence': 'yes...       other
# 59996  [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 59997  [{'answer': 'cat', 'answer_confidence': 'yes',...       other
# 59998  [{'answer': 'watermelon, sandwich, burger', 'a...       other
# 59999  [{'answer': 'soccer ball', 'answer_confidence'...       other
#
#                                   question_preprocessed answer_preprocessed
# 0                                     who looks happier                 man
# 1                            where is the woman sitting             blanket
# 2                              where is the man sitting               bench
# 3                                    is this man hungry                 yes
# 4                            what kind of drink is that                soda
# ...                                                 ...                 ...
# 59995  what color is the log the little girl sitting on               brown
# 59996             does the boy want to go on the seesaw                 yes
# 59997                what animal is between the two men                 cat
# 59998                 what food is by the picnic basket          watermelon
# 59999                           what is the man holding         soccer ball
#
# [60000 rows x 10 columns]

# %%
df_train = df_train.drop(['question', 'multiple_choice_answer'], axis=1)

cols = ['image_id','question_id','question_preprocessed','question_type','answer_preprocessed','answers','answer_type','multiple_choices']
df_train = df_train[cols]

print('Number of Question & Answer in MSCOCO Train Dataset:',len(df_train))
df_train.head(2)
# Out:
# Number of Question & Answer in MSCOCO Train Dataset: 60000
#    image_id  question_id       question_preprocessed question_type  \
# 0     11779       117792           who looks happier           who
# 1     11779       117790  where is the woman sitting  where is the
#
#   answer_preprocessed                                            answers  \
# 0                 man  [{'answer': 'old person', 'answer_confidence':...
# 1             blanket  [{'answer': 'on blanket', 'answer_confidence':...
#
#   answer_type                                   multiple_choices
# 0       other  [alive, 1, woman, purple, 2, yes, white, boy, ...
# 1       other  [3, no, blue, red, 1, slide, monkey bars, jump...

# %%
new_df_train = pd.merge(df_train, train_captions, on="image_id", how="left")
new_df_train
# Out:
#        image_id  question_id  \
# 0         11779       117792
# 1         11779       117790
# 2         11779       117791
# 3          5536        55360
# 4          5536        55361
# ...         ...          ...
# 59995     11695       116950
# 59996     11695       116951
# 59997     13790       137900
# 59998     13790       137901
# 59999     13790       137902
#
#                                   question_preprocessed      question_type  \
# 0                                     who looks happier                who
# 1                            where is the woman sitting       where is the
# 2                              where is the man sitting       where is the
# 3                                    is this man hungry            is this
# 4                            what kind of drink is that       what kind of
# ...                                                 ...                ...
# 59995  what color is the log the little girl sitting on  what color is the
# 59996             does the boy want to go on the seesaw           does the
# 59997                what animal is between the two men     what animal is
# 59998                 what food is by the picnic basket               what
# 59999                           what is the man holding    what is the man
#
#       answer_preprocessed                                            answers  \
# 0                     man  [{'answer': 'old person', 'answer_confidence':...
# 1                 blanket  [{'answer': 'on blanket', 'answer_confidence':...
# 2                   bench  [{'answer': 'on bench', 'answer_confidence': '...
# 3                     yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 4                    soda  [{'answer': 'water', 'answer_confidence': 'no'...
# ...                   ...                                                ...
# 59995               brown  [{'answer': 'brown', 'answer_confidence': 'yes...
# 59996                 yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 59997                 cat  [{'answer': 'cat', 'answer_confidence': 'yes',...
# 59998          watermelon  [{'answer': 'watermelon, sandwich, burger', 'a...
# 59999         soccer ball  [{'answer': 'soccer ball', 'answer_confidence'...
#
#       answer_type                                   multiple_choices  \
# 0           other  [alive, 1, woman, purple, 2, yes, white, boy, ...
# 1           other  [3, no, blue, red, 1, slide, monkey bars, jump...
# 2           other  [away, yes, blue, 1, 2, mouse, couch, no, yell...
# 3          yes/no  [water, yellow, 4, running, blue, pouring, out...
# 4           other  [wine, girl would fall, soda, white, yes, coke...
# ...           ...                                                ...
# 59995       other  [tan, brown, white, 1, running, red, 4, pink, ...
# 59996      yes/no  [red, no table, fetch, kicking soccer ball, ye...
# 59997       other  [dog, 4, yellow, 1, collectors, no, red, yes, ...
# 59998       other  [4, she is happy, grapes, pizza, white, becaus...
# 59999       other  [blue, cat, yellow, by fire, yes, pouring, roa...
#
#                                                      url  \
# 0      http://visualqa.org/data/abstract_v002/scene_i...
# 1      http://visualqa.org/data/abstract_v002/scene_i...
# 2      http://visualqa.org/data/abstract_v002/scene_i...
# 3      http://visualqa.org/data/abstract_v002/scene_i...
# 4      http://visualqa.org/data/abstract_v002/scene_i...
# ...                                                  ...
# 59995  http://visualqa.org/data/abstract_v002/scene_i...
# 59996  http://visualqa.org/data/abstract_v002/scene_i...
# 59997  http://visualqa.org/data/abstract_v002/scene_i...
# 59998  http://visualqa.org/data/abstract_v002/scene_i...
# 59999  http://visualqa.org/data/abstract_v002/scene_i...
#
#                                       file_name  width  height
# 0      abstract_v002_train2015_000000011779.png    700     400
# 1      abstract_v002_train2015_000000011779.png    700     400
# 2      abstract_v002_train2015_000000011779.png    700     400
# 3      abstract_v002_train2015_000000005536.png    700     400
# 4      abstract_v002_train2015_000000005536.png    700     400
# ...                                         ...    ...     ...
# 59995  abstract_v002_train2015_000000011695.png    700     400
# 59996  abstract_v002_train2015_000000011695.png    700     400
# 59997  abstract_v002_train2015_000000013790.png    700     400
# 59998  abstract_v002_train2015_000000013790.png    700     400
# 59999  abstract_v002_train2015_000000013790.png    700     400
#
# [60000 rows x 12 columns]

# %%
cols = ['file_name','question_id','question_preprocessed','question_type','answer_preprocessed','answers','answer_type','multiple_choices']
new_df_train = new_df_train[cols]

print('Number of Question & Answer in MSCOCO Train Dataset:',len(df_train))
new_df_train.head(2)
# Out:
# Number of Question & Answer in MSCOCO Train Dataset: 60000
#                                   file_name  question_id  \
# 0  abstract_v002_train2015_000000011779.png       117792
# 1  abstract_v002_train2015_000000011779.png       117790
#
#         question_preprocessed question_type answer_preprocessed  \
# 0           who looks happier           who                 man
# 1  where is the woman sitting  where is the             blanket
#
#                                              answers answer_type  \
# 0  [{'answer': 'old person', 'answer_confidence':...       other
# 1  [{'answer': 'on blanket', 'answer_confidence':...       other
#
#                                     multiple_choices
# 0  [alive, 1, woman, purple, 2, yes, white, boy, ...
# 1  [3, no, blue, red, 1, slide, monkey bars, jump...

# %%
new_df_train.rename(columns={"file_name": "image_id"}, inplace=True)
new_df_train
# Out:
#                                        image_id  question_id  \
# 0      abstract_v002_train2015_000000011779.png       117792
# 1      abstract_v002_train2015_000000011779.png       117790
# 2      abstract_v002_train2015_000000011779.png       117791
# 3      abstract_v002_train2015_000000005536.png        55360
# 4      abstract_v002_train2015_000000005536.png        55361
# ...                                         ...          ...
# 59995  abstract_v002_train2015_000000011695.png       116950
# 59996  abstract_v002_train2015_000000011695.png       116951
# 59997  abstract_v002_train2015_000000013790.png       137900
# 59998  abstract_v002_train2015_000000013790.png       137901
# 59999  abstract_v002_train2015_000000013790.png       137902
#
#                                   question_preprocessed      question_type  \
# 0                                     who looks happier                who
# 1                            where is the woman sitting       where is the
# 2                              where is the man sitting       where is the
# 3                                    is this man hungry            is this
# 4                            what kind of drink is that       what kind of
# ...                                                 ...                ...
# 59995  what color is the log the little girl sitting on  what color is the
# 59996             does the boy want to go on the seesaw           does the
# 59997                what animal is between the two men     what animal is
# 59998                 what food is by the picnic basket               what
# 59999                           what is the man holding    what is the man
#
#       answer_preprocessed                                            answers  \
# 0                     man  [{'answer': 'old person', 'answer_confidence':...
# 1                 blanket  [{'answer': 'on blanket', 'answer_confidence':...
# 2                   bench  [{'answer': 'on bench', 'answer_confidence': '...
# 3                     yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 4                    soda  [{'answer': 'water', 'answer_confidence': 'no'...
# ...                   ...                                                ...
# 59995               brown  [{'answer': 'brown', 'answer_confidence': 'yes...
# 59996                 yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 59997                 cat  [{'answer': 'cat', 'answer_confidence': 'yes',...
# 59998          watermelon  [{'answer': 'watermelon, sandwich, burger', 'a...
# 59999         soccer ball  [{'answer': 'soccer ball', 'answer_confidence'...
#
#       answer_type                                   multiple_choices
# 0           other  [alive, 1, woman, purple, 2, yes, white, boy, ...
# 1           other  [3, no, blue, red, 1, slide, monkey bars, jump...
# 2           other  [away, yes, blue, 1, 2, mouse, couch, no, yell...
# 3          yes/no  [water, yellow, 4, running, blue, pouring, out...
# 4           other  [wine, girl would fall, soda, white, yes, coke...
# ...           ...                                                ...
# 59995       other  [tan, brown, white, 1, running, red, 4, pink, ...
# 59996      yes/no  [red, no table, fetch, kicking soccer ball, ye...
# 59997       other  [dog, 4, yellow, 1, collectors, no, red, yes, ...
# 59998       other  [4, she is happy, grapes, pizza, white, becaus...
# 59999       other  [blue, cat, yellow, by fire, yes, pouring, roa...
#
# [60000 rows x 8 columns]

# %%
preprocessed_data_df = new_df_train.copy()

# %%
# create dataframe of unique answers and its counts in decending order of answer_count
answer_preprocessed = list(preprocessed_data_df['answer_preprocessed'])
count = {}
for i in answer_preprocessed:
    count[i] = count.get(i, 0) + 1

answer_df = pd.DataFrame(list(count.items()),columns=["answer","answer_count"])
answer_df["answer%"] = answer_df["answer_count"]/len(answer_preprocessed)*100
answer_df = answer_df.sort_values(by='answer_count',ascending=False)
answer_df.head(5)
# Out:
#    answer  answer_count    answer%
# 3     yes         14314  23.856667
# 7      no         10143  16.905000
# 15      2          3496   5.826667
# 16      1          1934   3.223333
# 32    red          1506   2.510000

# %%
new_df_train
# Out:
#                                        image_id  question_id  \
# 0      abstract_v002_train2015_000000011779.png       117792
# 1      abstract_v002_train2015_000000011779.png       117790
# 2      abstract_v002_train2015_000000011779.png       117791
# 3      abstract_v002_train2015_000000005536.png        55360
# 4      abstract_v002_train2015_000000005536.png        55361
# ...                                         ...          ...
# 59995  abstract_v002_train2015_000000011695.png       116950
# 59996  abstract_v002_train2015_000000011695.png       116951
# 59997  abstract_v002_train2015_000000013790.png       137900
# 59998  abstract_v002_train2015_000000013790.png       137901
# 59999  abstract_v002_train2015_000000013790.png       137902
#
#                                   question_preprocessed      question_type  \
# 0                                     who looks happier                who
# 1                            where is the woman sitting       where is the
# 2                              where is the man sitting       where is the
# 3                                    is this man hungry            is this
# 4                            what kind of drink is that       what kind of
# ...                                                 ...                ...
# 59995  what color is the log the little girl sitting on  what color is the
# 59996             does the boy want to go on the seesaw           does the
# 59997                what animal is between the two men     what animal is
# 59998                 what food is by the picnic basket               what
# 59999                           what is the man holding    what is the man
#
#       answer_preprocessed                                            answers  \
# 0                     man  [{'answer': 'old person', 'answer_confidence':...
# 1                 blanket  [{'answer': 'on blanket', 'answer_confidence':...
# 2                   bench  [{'answer': 'on bench', 'answer_confidence': '...
# 3                     yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 4                    soda  [{'answer': 'water', 'answer_confidence': 'no'...
# ...                   ...                                                ...
# 59995               brown  [{'answer': 'brown', 'answer_confidence': 'yes...
# 59996                 yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 59997                 cat  [{'answer': 'cat', 'answer_confidence': 'yes',...
# 59998          watermelon  [{'answer': 'watermelon, sandwich, burger', 'a...
# 59999         soccer ball  [{'answer': 'soccer ball', 'answer_confidence'...
#
#       answer_type                                   multiple_choices
# 0           other  [alive, 1, woman, purple, 2, yes, white, boy, ...
# 1           other  [3, no, blue, red, 1, slide, monkey bars, jump...
# 2           other  [away, yes, blue, 1, 2, mouse, couch, no, yell...
# 3          yes/no  [water, yellow, 4, running, blue, pouring, out...
# 4           other  [wine, girl would fall, soda, white, yes, coke...
# ...           ...                                                ...
# 59995       other  [tan, brown, white, 1, running, red, 4, pink, ...
# 59996      yes/no  [red, no table, fetch, kicking soccer ball, ye...
# 59997       other  [dog, 4, yellow, 1, collectors, no, red, yes, ...
# 59998       other  [4, she is happy, grapes, pizza, white, becaus...
# 59999       other  [blue, cat, yellow, by fire, yes, pouring, roa...
#
# [60000 rows x 8 columns]

# %%
top_300_answers = list(answer_df['answer'])[:300]

new_data_df_300 = pd.DataFrame()
for i in (range(len(top_300_answers))):
  new_data_df_300 = pd.concat([new_data_df_300, preprocessed_data_df[preprocessed_data_df.answer_preprocessed == top_300_answers[i]]])

print(f"Top 300 answers coverd {round(len(new_data_df_300)/len(preprocessed_data_df)*100,2)}% of datapoints")
# Out:
# Top 300 answers coverd 93.0% of datapoints

# %%
new_data_df_300
# Out:
#                                        image_id  question_id  \
# 3      abstract_v002_train2015_000000005536.png        55360
# 14     abstract_v002_train2015_000000006502.png        65022
# 20     abstract_v002_train2015_000000008788.png        87882
# 26     abstract_v002_train2015_000000001527.png        15271
# 27     abstract_v002_train2015_000000002592.png        25920
# ...                                         ...          ...
# 26820  abstract_v002_train2015_000000013104.png       131040
# 31225  abstract_v002_train2015_000000013156.png       131561
# 54247  abstract_v002_train2015_000000008881.png        88811
# 54387  abstract_v002_train2015_000000017305.png       173050
# 55831  abstract_v002_train2015_000000002416.png        24161
#
#                                    question_preprocessed      question_type  \
# 3                                     is this man hungry            is this
# 14                            is the man eating a hotdog         is the man
# 20                          is the mouse under the chair             is the
# 26                                    is the man falling         is the man
# 27                         is little baby trying to walk                 is
# ...                                                  ...                ...
# 26820                     what is the young man touching        what is the
# 31225                             what is next to the tv            what is
# 54247      what can be used for electronic entertainment               what
# 54387  what is the woman on the right holding in her ...  what is the woman
# 55831                               what is on the table     what is on the
#
#       answer_preprocessed                                            answers  \
# 3                     yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 14                    yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 20                    yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 26                    yes  [{'answer': 'yes', 'answer_confidence': 'maybe...
# 27                    yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# ...                   ...                                                ...
# 26820        game console  [{'answer': 'game console', 'answer_confidence...
# 31225        game console  [{'answer': 'dvd player', 'answer_confidence':...
# 54247        game console  [{'answer': 'game consul', 'answer_confidence'...
# 54387        game console  [{'answer': 'game console', 'answer_confidence...
# 55831        game console  [{'answer': 'game console', 'answer_confidence...
#
#       answer_type                                   multiple_choices
# 3          yes/no  [water, yellow, 4, running, blue, pouring, out...
# 14         yes/no  [2, 3, 1, ended, white, yellow, yo-yo, maybe, ...
# 20         yes/no  [chairs, boy chasing girl, 2, casually, almost...
# 26         yes/no  [wheat, being held, 3, fell, white, yes, sunfl...
# 27         yes/no  [white, blue, mo, they're on upper shelves, es...
# ...           ...                                                ...
# 26820       other  [1, yes, to pick him up, yellow, jump on table...
# 31225       other  [she fell, table, 4, 2, game console, cement, ...
# 54247       other  [basket, lots, white, one sitting, no, yellow,...
# 54387       other  [3, under man's arm, from bottle, yellow, 1, w...
# 55831       other  [cat, falling, yes, 1, 2, no, red, cups, yello...
#
# [55799 rows x 8 columns]

# %%
labelencoder = preprocessing.LabelEncoder()
labelencoder.fit(top_300_answers)
new_data_df_300['class_label'] = labelencoder.transform(list(new_data_df_300['answer_preprocessed']))
print("Number of Class Labels:",len(labelencoder.classes_))

new_data_df_300 = new_data_df_300.drop(['question_id', 'question_type', 'answer_type'], axis=1)
print("Number of datapoints of final dataset:",len(new_data_df_300))
new_data_df_300.to_csv("/content/drive/MyDrive/VQA assignment/preprocessed_k300.csv",index=False)
new_data_df_300.head(3)
# Out:
# Number of Class Labels: 300
# Number of datapoints of final dataset: 55799
#                                     image_id         question_preprocessed  \
# 3   abstract_v002_train2015_000000005536.png            is this man hungry
# 14  abstract_v002_train2015_000000006502.png    is the man eating a hotdog
# 20  abstract_v002_train2015_000000008788.png  is the mouse under the chair
#
#    answer_preprocessed                                            answers  \
# 3                  yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 14                 yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
# 20                 yes  [{'answer': 'yes', 'answer_confidence': 'yes',...
#
#                                      multiple_choices  class_label
# 3   [water, yellow, 4, running, blue, pouring, out...          299
# 14  [2, 3, 1, ended, white, yellow, yo-yo, maybe, ...          299
# 20  [chairs, boy chasing girl, 2, casually, almost...          299

# %%
class_labels = labelencoder.classes_
print("Class labels:", class_labels)


for index, label in enumerate(class_labels):
    print(f"Class label {index}: {label}")


unique_class_labels = new_data_df_300['class_label'].unique()
print("Unique class labels in the dataset:", unique_class_labels)
# Out:
# Class labels: ['0' '1' '10' '11' '12' '16' '18' '2' '3' '4' '5' '6' '7' '8' '9' 'abcd'
#  'afternoon' 'apple' 'apples' 'baby' 'ball' 'baseball' 'basket' 'bat'
#  'bear' 'bed' 'beehive' 'bees' 'begging' 'behind cloud' 'behind tree'
#  'beige' 'bench' 'bicycle' 'bike' 'bird' 'birds' 'black' 'black and white'
#  'blanket' 'blocks' 'blonde' 'blue' 'bone' 'book' 'books' 'bookshelf'
#  'bottle' 'boy' 'bread' 'brown' 'bucket' 'burger' 'bush' 'bushes'
#  'butterflies' 'butterfly' 'by pond' 'by tree' 'cake' 'camera' 'car' 'cat'
#  'cats' 'chair' 'checkered' 'cheese' 'chihuahua' 'closed' 'cloud' 'clouds'
#  'cloudy' 'coat rack' 'cold' 'cooking' 'corn' 'couch' 'cup' 'curtains'
#  'daisies' 'dancing' 'day' 'daytime' 'deer' 'dessert' 'dog' 'dogs' 'doll'
#  'dollhouse' 'door' 'drinking' 'duck' 'ducks' 'eagle' 'eating' 'eggs'
#  'evening' 'fall' 'female' 'fire' 'fireplace' 'fish' 'floor' 'floral'
#  'flower' 'flowers' 'flying' 'food' 'football' 'friends' 'frisbee' 'frog'
#  'game console' 'girl' 'glass' 'gold' 'gone' 'grass' 'gray' 'green'
#  'green and yellow' 'grill' 'grilling' 'ground' 'hamburger' 'happy'
#  'holding hands' 'holding it' 'hot dog' 'hot dogs' 'in air' 'in pond'
#  'in sky' 'in tree' 'jump rope' 'jumping' 'jumping rope' 'koi' 'laughing'
#  'laying down' 'left' 'legos' 'lily pad' 'lily pads' 'living room' 'log'
#  'logs' 'male' 'man' 'mantle' 'marshmallow' 'marshmallows' 'meat' 'mice'
#  'middle' 'monkey bars' 'moon' 'morning' 'mouse' 'mushroom' 'mushrooms'
#  'nest' 'no' 'no one' 'nobody' 'none' 'noon' 'nothing' 'nowhere' 'old'
#  'old man' 'on' 'on bench' 'on blanket' 'on couch' 'on floor' 'on grass'
#  'on ground' 'on left' 'on mantle' 'on rug' 'on table' 'open' 'orange'
#  'orange and white' 'ottoman' 'outside' 'owl' 'painting' 'park' 'people'
#  'petting dog' 'picnic' 'picture' 'pictures' 'pie' 'pigtails' 'pillow'
#  'pillows' 'pine' 'pink' 'pizza' 'plant' 'plants' 'plate' 'playing'
#  'playing on monkey bars' 'playing with dog' 'pond' 'pug' 'purple'
#  'rabbit' 'raccoon' 'reading' 'rectangle' 'red' 'red and white' 'resting'
#  'ribs' 'right' 'roasting marshmallows' 'robot' 'rocks' 'rose' 'round'
#  'rug' 'running' 'sad' 'salad' 'sand' 'sandbox' 'sandwich' 'scared'
#  'scooter' 'see saw' 'seesaw' 'shelf' 'short' 'shovel' 'sidewalk'
#  'sitting' 'skateboard' 'skateboarding' 'sky' 'sleeping' 'slide' 'sliding'
#  'soccer' 'soccer ball' 'sofa' 'squirrel' 'squirrels' 'standing' 'steak'
#  'steaks' 'stool' 'stools' 'stuffed animal' 'summer' 'sun' 'sunny'
#  'sunset' 'table' 'tablecloth' 'talking' 'tan' 'tea' 'tea set'
#  'teddy bear' 'tired' 'tongs' 'toy' 'toys' 'train' 'tree' 'triangle'
#  'turtle' 'turtles' 'tv' 'under table' 'under tree' 'under window' 'up'
#  'walking' 'wall' 'watching tv' 'water' 'watermelon' 'waving' 'white'
#  'window' 'wine' 'wine bottle' 'wine glass' 'woman' 'wood' 'yarn' 'yellow'
#  'yellow and white' 'yes']
# Class label 0: 0
# Class label 1: 1
# Class label 2: 10
# Class label 3: 11
# Class label 4: 12
# Class label 5: 16
# Class label 6: 18
# Class label 7: 2
# Class label 8: 3
# Class label 9: 4
# Class label 10: 5
# Class label 11: 6
# Class label 12: 7
# Class label 13: 8
# Class label 14: 9
# Class label 15: abcd
# Class label 16: afternoon
# Class label 17: apple
# Class label 18: apples
# Class label 19: baby
# Class label 20: ball
# Class label 21: baseball
# Class label 22: basket
# Class label 23: bat
# Class label 24: bear
# Class label 25: bed
# Class label 26: beehive
# Class label 27: bees
# Class label 28: begging
# Class label 29: behind cloud
# Class label 30: behind tree
# Class label 31: beige
# Class label 32: bench
# Class label 33: bicycle
# Class label 34: bike
# Class label 35: bird
# Class label 36: birds
# Class label 37: black
# Class label 38: black and white
# Class label 39: blanket
# Class label 40: blocks
# Class label 41: blonde
# Class label 42: blue
# Class label 43: bone
# Class label 44: book
# Class label 45: books
# Class label 46: bookshelf
# Class label 47: bottle
# Class label 48: boy
# Class label 49: bread
# Class label 50: brown
# Class label 51: bucket
# Class label 52: burger
# Class label 53: bush
# Class label 54: bushes
# Class label 55: butterflies
# Class label 56: butterfly
# Class label 57: by pond
# Class label 58: by tree
# Class label 59: cake
# Class label 60: camera
# Class label 61: car
# Class label 62: cat
# Class label 63: cats
# Class label 64: chair
# Class label 65: checkered
# Class label 66: cheese
# Class label 67: chihuahua
# Class label 68: closed
# Class label 69: cloud
# Class label 70: clouds
# Class label 71: cloudy
# Class label 72: coat rack
# Class label 73: cold
# Class label 74: cooking
# Class label 75: corn
# Class label 76: couch
# Class label 77: cup
# Class label 78: curtains
# Class label 79: daisies
# Class label 80: dancing
# Class label 81: day
# Class label 82: daytime
# Class label 83: deer
# Class label 84: dessert
# Class label 85: dog
# Class label 86: dogs
# Class label 87: doll
# Class label 88: dollhouse
# Class label 89: door
# Class label 90: drinking
# Class label 91: duck
# Class label 92: ducks
# Class label 93: eagle
# Class label 94: eating
# Class label 95: eggs
# Class label 96: evening
# Class label 97: fall
# Class label 98: female
# Class label 99: fire
# Class label 100: fireplace
# Class label 101: fish
# Class label 102: floor
# Class label 103: floral
# Class label 104: flower
# Class label 105: flowers
# Class label 106: flying
# Class label 107: food
# Class label 108: football
# Class label 109: friends
# Class label 110: frisbee
# Class label 111: frog
# Class label 112: game console
# Class label 113: girl
# Class label 114: glass
# Class label 115: gold
# Class label 116: gone
# Class label 117: grass
# Class label 118: gray
# Class label 119: green
# Class label 120: green and yellow
# Class label 121: grill
# Class label 122: grilling
# Class label 123: ground
# Class label 124: hamburger
# Class label 125: happy
# Class label 126: holding hands
# Class label 127: holding it
# Class label 128: hot dog
# Class label 129: hot dogs
# Class label 130: in air
# Class label 131: in pond
# Class label 132: in sky
# Class label 133: in tree
# Class label 134: jump rope
# Class label 135: jumping
# Class label 136: jumping rope
# Class label 137: koi
# Class label 138: laughing
# Class label 139: laying down
# Class label 140: left
# Class label 141: legos
# Class label 142: lily pad
# Class label 143: lily pads
# Class label 144: living room
# Class label 145: log
# Class label 146: logs
# Class label 147: male
# Class label 148: man
# Class label 149: mantle
# Class label 150: marshmallow
# Class label 151: marshmallows
# Class label 152: meat
# Class label 153: mice
# Class label 154: middle
# Class label 155: monkey bars
# Class label 156: moon
# Class label 157: morning
# Class label 158: mouse
# Class label 159: mushroom
# Class label 160: mushrooms
# Class label 161: nest
# Class label 162: no
# Class label 163: no one
# Class label 164: nobody
# Class label 165: none
# Class label 166: noon
# Class label 167: nothing
# Class label 168: nowhere
# Class label 169: old
# Class label 170: old man
# Class label 171: on
# Class label 172: on bench
# Class label 173: on blanket
# Class label 174: on couch
# Class label 175: on floor
# Class label 176: on grass
# Class label 177: on ground
# Class label 178: on left
# Class label 179: on mantle
# Class label 180: on rug
# Class label 181: on table
# Class label 182: open
# Class label 183: orange
# Class label 184: orange and white
# Class label 185: ottoman
# Class label 186: outside
# Class label 187: owl
# Class label 188: painting
# Class label 189: park
# Class label 190: people
# Class label 191: petting dog
# Class label 192: picnic
# Class label 193: picture
# Class label 194: pictures
# Class label 195: pie
# Class label 196: pigtails
# Class label 197: pillow
# Class label 198: pillows
# Class label 199: pine
# Class label 200: pink
# Class label 201: pizza
# Class label 202: plant
# Class label 203: plants
# Class label 204: plate
# Class label 205: playing
# Class label 206: playing on monkey bars
# Class label 207: playing with dog
# Class label 208: pond
# Class label 209: pug
# Class label 210: purple
# Class label 211: rabbit
# Class label 212: raccoon
# Class label 213: reading
# Class label 214: rectangle
# Class label 215: red
# Class label 216: red and white
# Class label 217: resting
# Class label 218: ribs
# Class label 219: right
# Class label 220: roasting marshmallows
# Class label 221: robot
# Class label 222: rocks
# Class label 223: rose
# Class label 224: round
# Class label 225: rug
# Class label 226: running
# Class label 227: sad
# Class label 228: salad
# Class label 229: sand
# Class label 230: sandbox
# Class label 231: sandwich
# Class label 232: scared
# Class label 233: scooter
# Class label 234: see saw
# Class label 235: seesaw
# Class label 236: shelf
# Class label 237: short
# Class label 238: shovel
# Class label 239: sidewalk
# Class label 240: sitting
# Class label 241: skateboard
# Class label 242: skateboarding
# Class label 243: sky
# Class label 244: sleeping
# Class label 245: slide
# Class label 246: sliding
# Class label 247: soccer
# Class label 248: soccer ball
# Class label 249: sofa
# Class label 250: squirrel
# Class label 251: squirrels
# Class label 252: standing
# Class label 253: steak
# Class label 254: steaks
# Class label 255: stool
# Class label 256: stools
# Class label 257: stuffed animal
# Class label 258: summer
# Class label 259: sun
# Class label 260: sunny
# Class label 261: sunset
# Class label 262: table
# Class label 263: tablecloth
# Class label 264: talking
# Class label 265: tan
# Class label 266: tea
# Class label 267: tea set
# Class label 268: teddy bear
# Class label 269: tired
# Class label 270: tongs
# Class label 271: toy
# Class label 272: toys
# Class label 273: train
# Class label 274: tree
# Class label 275: triangle
# Class label 276: turtle
# Class label 277: turtles
# Class label 278: tv
# Class label 279: under table
# Class label 280: under tree
# Class label 281: under window
# Class label 282: up
# Class label 283: walking
# Class label 284: wall
# Class label 285: watching tv
# Class label 286: water
# Class label 287: watermelon
# Class label 288: waving
# Class label 289: white
# Class label 290: window
# Class label 291: wine
# Class label 292: wine bottle
# Class label 293: wine glass
# Class label 294: woman
# Class label 295: wood
# Class label 296: yarn
# Class label 297: yellow
# Class label 298: yellow and white
# Class label 299: yes
# Unique class labels in the dataset: [299 162   7   1 215   8 289 297  42   9  85  50   0  62  10 240 119  37
#  118 291 205 247 102  76 262 219 108 294 107 167 225 287 140 202 113 183
#  244 145  48  32  39 155 148 255  17 252 117  35 260  34  43 230 195  44
#   21  64 250 233 265 193 296 274 278  26 158 208  19 259 241 253 283 135
#  163  91 216 100 103 268  99  83  80  11 245 146 125 243 239 261 248 212
#  101 200 218 105 110 276 229  40  72 226  93  94 211  87 189  56 196  31
#  201  65 221 144  20 288 134 151  77  92 181 231 238 285  22  27 136 192
#  174 235 175  13 197 187  81 137  69 210 156 284 124 161 160 149  66 173
#  150 267 272  98 180  53 128 295   2 266  88 121 176 123  97  68  25 122
#  217 111  51  18  36  12 169  61   3 246  49  78  15 280 290 213  74 234
#  159 270  47 138 147  55 185 222 286  16  23 258 279 194  67   6 165 154
#  164 115  41  30 214 275 168  38 141 273 131  45   5 203  90  28 116 242
#  199 293 269  96  75 204 254 166 209 198 237  70 207 133 143 188 177 178
#   89 114 228 120 104 292 190 184 126  95   4 223 271 142  24 186 130 129
#  153 257  46 106  33 232 132 182 224 139  52  54  84 109 281 172 263 236
#  264  71 206 256  58  59  82  29  79 170  63  14 282 152 220 249 179  60
#  171  73 227 157  57  86 251 127 298 277 191 112]

# %%
X = new_data_df_300[['image_id','question_preprocessed','answer_preprocessed']]
y = new_data_df_300['class_label']
print('X.shape:',X.shape)
print('y.shape:',y.shape)

new_data_df_300.groupby(by='class_label').count()
# Out:
# X.shape: (55799, 3)
# y.shape: (55799,)
#              image_id  question_preprocessed  answer_preprocessed  answers  \
# class_label
# 0                 467                    467                  467      467
# 1                1934                   1934                 1934     1934
# 2                  38                     38                   38       38
# 3                  32                     32                   32       32
# 4                  17                     17                   17       17
# ...               ...                    ...                  ...      ...
# 295                38                     38                   38       38
# 296               123                    123                  123      123
# 297               603                    603                  603      603
# 298                12                     12                   12       12
# 299             14314                  14314                14314    14314
#
#              multiple_choices
# class_label
# 0                         467
# 1                        1934
# 2                          38
# 3                          32
# 4                          17
# ...                       ...
# 295                        38
# 296                       123
# 297                       603
# 298                        12
# 299                     14314
#
# [300 rows x 5 columns]

# %%
X
# Out:
#                                        image_id  \
# 3      abstract_v002_train2015_000000005536.png
# 14     abstract_v002_train2015_000000006502.png
# 20     abstract_v002_train2015_000000008788.png
# 26     abstract_v002_train2015_000000001527.png
# 27     abstract_v002_train2015_000000002592.png
# ...                                         ...
# 26820  abstract_v002_train2015_000000013104.png
# 31225  abstract_v002_train2015_000000013156.png
# 54247  abstract_v002_train2015_000000008881.png
# 54387  abstract_v002_train2015_000000017305.png
# 55831  abstract_v002_train2015_000000002416.png
#
#                                    question_preprocessed answer_preprocessed
# 3                                     is this man hungry                 yes
# 14                            is the man eating a hotdog                 yes
# 20                          is the mouse under the chair                 yes
# 26                                    is the man falling                 yes
# 27                         is little baby trying to walk                 yes
# ...                                                  ...                 ...
# 26820                     what is the young man touching        game console
# 31225                             what is next to the tv        game console
# 54247      what can be used for electronic entertainment        game console
# 54387  what is the woman on the right holding in her ...        game console
# 55831                               what is on the table        game console
#
# [55799 rows x 3 columns]

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.10, stratify=y, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.10, stratify=y_train, random_state=42)

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)

# Convert a class vector y_train and y_test to binary class matrix
Y_train = to_categorical(y_train, 1000)
Y_val = to_categorical(y_val, 1000)
Y_test = to_categorical(y_test, 1000)
# Out:
# (45197, 3) (45197,)
# (5580, 3) (5580,)
# (5022, 3) (5022,)

# %%
X_train
# Out:
#                                        image_id  \
# 28698  abstract_v002_train2015_000000016721.png
# 8522   abstract_v002_train2015_000000012888.png
# 8017   abstract_v002_train2015_000000014923.png
# 43876  abstract_v002_train2015_000000014320.png
# 30907  abstract_v002_train2015_000000014085.png
# ...                                         ...
# 35378  abstract_v002_train2015_000000007355.png
# 56392  abstract_v002_train2015_000000010309.png
# 32087  abstract_v002_train2015_000000013969.png
# 37397  abstract_v002_train2015_000000017516.png
# 6377   abstract_v002_train2015_000000010479.png
#
#                          question_preprocessed answer_preprocessed
# 28698                   what color is the bird              yellow
# 8522                     what color is the cat               white
# 8017                       is the girl jumping                  no
# 43876         what game the people are playing             frisbee
# 30907    what is the yellow object on the tree             beehive
# ...                                        ...                 ...
# 35378      how many people are in this picture                   1
# 56392    what kind of wine is the man drinking                 red
# 32087  is the woman preparing to catch the cat                  no
# 37397             does everyone have a red cup                 yes
# 6377        is the dog trying to join the game                 yes
#
# [45197 rows x 3 columns]

# %%
aug1 = iaa.Fliplr(0.5)
aug2 = iaa.AddToBrightness((-30,-20))
aug3 = iaa.LinearContrast((0.6, 0.75))

# %%
class CustomDataGen_aug(tf.keras.utils.Sequence):

    def __init__(self, X_que, X_img, y,
                 batch_size,
                 shuffle=True):

        self.X_que = X_que
        self.X_img = X_img
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(y))

    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

    def __get_input1(self, que):

        que_arr = (pad_sequences(t.texts_to_sequences([que]), maxlen=22, padding='post'))[0]
        return que_arr

    def __get_input2(self, path):

        img = cv2.imread(path)

        a = np.random.uniform()
        if a<0.25:
            img = aug1.augment_image(img)
        elif a<0.5:
            img = aug2.augment_image(img)
        elif a<0.75:
            img = aug3.augment_image(img)
        else:
            img = img

        img = np.array(img)/255.0

        return img

    def __get_output(self, label):
        return tf.keras.utils.to_categorical(label, num_classes=300)

    def __getitem__(self, index):

        batch_x0 = self.X_que[index * self.batch_size:(index + 1) * self.batch_size]
        batch_x1 = self.X_img[index * self.batch_size:(index + 1) * self.batch_size]
        batch_y = self.y[index * self.batch_size:(index + 1) * self.batch_size]

        X0_batch = np.asarray([self.__get_input1(que) for que in batch_x0])
        X1_batch = np.asarray([self.__get_input2(colab_path+path) for path in batch_x1])
        y_batch = np.asarray([self.__get_output(c) for c in batch_y])

        return tuple([X0_batch, X1_batch]), y_batch

    def __len__(self):
        return len(self.indexes) // self.batch_size


class CustomDataGen(tf.keras.utils.Sequence):

    def __init__(self, X_que, X_img, y,
                 batch_size,
                 shuffle=True):

        self.X_que = X_que
        self.X_img = X_img
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(y))

    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

    def __get_input1(self, que):

        que_arr = (pad_sequences(t.texts_to_sequences([que]), maxlen=22, padding='post'))[0]
        return que_arr

    def __get_input2(self, path):

        img = cv2.imread(path)
        img = np.array(img)/255.0

        return img

    def __get_output(self, label):
        return tf.keras.utils.to_categorical(label, num_classes=300)

    def __getitem__(self, index):

        batch_x0 = self.X_que[index * self.batch_size:(index + 1) * self.batch_size]
        batch_x1 = self.X_img[index * self.batch_size:(index + 1) * self.batch_size]
        batch_y = self.y[index * self.batch_size:(index + 1) * self.batch_size]

        X0_batch = np.asarray([self.__get_input1(que) for que in batch_x0])
        X1_batch = np.asarray([self.__get_input2(colab_path+path) for path in batch_x1])
        y_batch = np.asarray([self.__get_output(c) for c in batch_y])

        return tuple([X0_batch, X1_batch]), y_batch

    def __len__(self):
        return len(self.indexes) // self.batch_size

colab_path = "/content/drive/MyDrive/VQA assignment/scene_img_abstract_v002_train2015"
batch_siz = 128
traingen = CustomDataGen_aug(list(X_train['question_preprocessed']),list(X_train['image_id']),list(y_train),batch_size=batch_siz)
valgen = CustomDataGen(list(X_val['question_preprocessed']),list(X_val['image_id']),list(y_val),batch_size=batch_siz)

# %%
# Train Validation & Test Text vectorization
t = Tokenizer(filters='')
t.fit_on_texts(list(X_train['question_preprocessed']))
vocab_size = len(t.word_index) + 1



train_sequences = t.texts_to_sequences(list(X_train['question_preprocessed']))
train_padded_docs = pad_sequences(train_sequences, maxlen=22, padding='post')

val_sequences = t.texts_to_sequences(list(X_val['question_preprocessed']))
val_padded_docs = pad_sequences(val_sequences, maxlen=22, padding='post')

test_sequences = t.texts_to_sequences(list(X_test['question_preprocessed']))
test_padded_docs = pad_sequences(test_sequences, maxlen=22, padding='post')

# %%
import numpy as np


glove_file = '/content/drive/MyDrive/VQA assignment/glove.6B.300d.txt'
embedding_index = {}


with open(glove_file, encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs

print('total loaded %s word vectors.' % len(embedding_index))
# Out:
# total loaded 400000 word vectors.

# %%
def embedding_for_vocab(filepath, word_index,embedding_dim):
    vocab_size = len(word_index) + 1

    # Adding again 1 because of reserved 0 index
    embedding_matrix_vocab = np.zeros((vocab_size,
                                       embedding_dim))

    with open(filepath, encoding="utf8") as f:
        for line in f:
            word, *vector = line.split()
            if word in word_index:
                idx = word_index[word]
                embedding_matrix_vocab[idx] = np.array(
                    vector, dtype=np.float32)[:embedding_dim]

    return embedding_matrix_vocab


# matrix for vocab: word_index
embedding_dim = 300
embedding_matrix_vocab = embedding_for_vocab(
    '/content/drive/MyDrive/VQA assignment/glove.6B.300d.txt', t.word_index,
  embedding_dim)

print("Dense vector for first word is => ",
      embedding_matrix_vocab[1])
# Out:
# Dense vector for first word is =>  [ 4.65600006e-02  2.13180006e-01 -7.43639981e-03 -4.58539993e-01
#  -3.56389992e-02  2.36430004e-01 -2.88360000e-01  2.15210006e-01
#  -1.34859994e-01 -1.64129996e+00 -2.60910004e-01  3.24340016e-02
#   5.66210002e-02 -4.32960019e-02 -2.16719992e-02  2.24759996e-01
#  -7.51290023e-02 -6.70180023e-02 -1.42470002e-01  3.88250016e-02
#  -1.89510003e-01  2.99769998e-01  3.93049985e-01  1.78870007e-01
#  -1.73429996e-01 -2.11779997e-01  2.36169994e-01 -6.36809990e-02
#  -4.23180014e-01 -1.16609998e-01  9.37540010e-02  1.72959998e-01
#  -3.30729991e-01  4.91120011e-01 -6.89949989e-01 -9.24620032e-02
#   2.47419998e-01 -1.79910004e-01  9.79079977e-02  8.31179991e-02
#   1.52989998e-01 -2.72760004e-01 -3.89339998e-02  5.44529974e-01
#   5.37370026e-01  2.91049987e-01 -7.35139987e-03  4.78800014e-02
#  -4.07599986e-01 -2.67590005e-02  1.79189995e-01  1.09770000e-02
#  -1.09630004e-01 -2.63949990e-01  7.39900023e-02  2.62360007e-01
#  -1.50800005e-01  3.46230000e-01  2.57580012e-01  1.19709998e-01
#  -3.71350013e-02 -7.15930015e-02  4.38980013e-01 -4.07640003e-02
#   1.64250005e-02 -4.46399987e-01  1.71969995e-01  4.62459996e-02
#   5.86390011e-02  4.14990000e-02  5.39479971e-01  5.24950027e-01
#   1.13609999e-01 -4.83149998e-02 -3.63849998e-01  1.87040001e-01
#   9.27610025e-02 -1.11290000e-01 -4.20850009e-01  1.39919996e-01
#  -3.93379986e-01 -6.79450035e-02  1.21880002e-01  1.67070001e-01
#   7.51689970e-02 -1.55290002e-02 -1.94989994e-01  1.96380004e-01
#   5.31940013e-02  2.51700014e-01 -3.48450005e-01 -1.06380001e-01
#  -3.46920013e-01 -1.90239996e-01 -2.00399995e-01  1.21540003e-01
#  -2.92079985e-01  2.33529992e-02 -1.16180003e-01 -3.57679993e-01
#   6.23040013e-02  3.58839989e-01  2.90600006e-02  7.30049983e-03
#   4.94820019e-03 -1.50480002e-01 -1.23130001e-01  1.93370000e-01
#   1.21730000e-01  4.45030004e-01  2.51470000e-01  1.07809998e-01
#  -1.77159995e-01  3.86909992e-02  8.15299973e-02  1.46669999e-01
#   6.36660010e-02  6.13319986e-02 -7.55689964e-02 -3.77240002e-01
#   1.58500001e-02 -3.03420007e-01  2.83740014e-01 -4.20130007e-02
#  -4.07150015e-02 -1.52689993e-01  7.49799982e-02  1.55770004e-01
#   1.04330003e-01  3.13930005e-01  1.93090007e-01  1.94289997e-01
#   1.51850000e-01 -1.01920001e-01 -1.87849998e-02  2.07910001e-01
#   1.33660004e-01  1.90380007e-01 -2.55580008e-01  3.03999990e-01
#  -1.89599991e-02  2.01470003e-01 -4.21099991e-01 -7.51559995e-03
#  -2.79769987e-01 -1.93140000e-01  4.62040007e-02  1.99709997e-01
#  -3.02069992e-01  2.57349998e-01  6.81070030e-01 -1.94089994e-01
#   2.39840001e-01  2.24930003e-01  6.52239978e-01 -1.35609999e-01
#  -1.73830003e-01 -4.82090004e-02 -1.18600003e-01  2.15879991e-03
#  -1.95250008e-02  1.19479999e-01  1.93460003e-01 -4.08199996e-01
#  -8.29659998e-02  1.66260004e-01 -1.06009997e-01  3.58610004e-01
#   1.69220001e-01  7.25900009e-02 -2.48030007e-01 -1.00240000e-01
#  -5.24909973e-01 -1.77450001e-01 -3.66470009e-01  2.61799991e-01
#  -1.20770000e-02  8.31900015e-02 -2.15279996e-01  4.10450011e-01
#   2.91359991e-01  3.08690012e-01  7.88640007e-02  3.22070003e-01
#  -4.10230011e-02 -1.09700002e-01 -9.20410007e-02 -1.23389997e-01
#  -1.64159998e-01  3.53819996e-01 -8.27739984e-02  3.31710011e-01
#  -2.47380003e-01 -4.89280000e-02  1.57460004e-01  1.89879999e-01
#  -2.66420003e-02  6.33149967e-02 -1.06729995e-02  3.40889990e-01
#   1.41059995e+00  1.34169996e-01  2.81910002e-01 -2.59400010e-01
#   5.52669987e-02 -5.24250008e-02 -2.57889986e-01  1.91270001e-02
#  -2.20839996e-02  3.21130008e-01  6.88180029e-02  5.12070000e-01
#   1.64780006e-01 -2.01940000e-01  2.92320013e-01  9.85750034e-02
#   1.31449997e-02 -1.06519997e-01  1.35100007e-01 -4.53319997e-02
#   2.06970006e-01 -4.84250009e-01 -4.47059989e-01  3.33050010e-03
#   2.92639993e-03 -1.09750003e-01 -2.33250007e-01  2.24419996e-01
#  -1.05030000e-01  1.23389997e-01  1.09779999e-01  4.89940010e-02
#  -2.51569986e-01  4.03189987e-01  3.53179991e-01  1.86509997e-01
#  -2.36220006e-02 -1.27340004e-01  1.14749998e-01  2.73589998e-01
#  -2.18659997e-01  1.57939997e-02  8.17539990e-01 -2.37920005e-02
#  -8.54690015e-01 -1.62029997e-01  1.80759996e-01  2.80140005e-02
#  -1.43399999e-01  1.31389999e-03 -9.17349979e-02 -8.97039995e-02
#   1.11050002e-01 -1.67030007e-01  6.83770031e-02 -8.73880014e-02
#  -3.97889987e-02  1.41840000e-02  2.11870000e-01  2.85789996e-01
#  -2.87970006e-01 -5.89959994e-02 -3.24359983e-02 -4.70090006e-03
#  -1.70519993e-01 -3.47409993e-02 -1.14890002e-01  7.50930011e-02
#   9.95260030e-02  4.81830016e-02 -7.37750009e-02 -4.18170005e-01
#   4.12680022e-03  4.44139987e-01 -1.60620004e-01  1.42940000e-01
#  -2.26279998e+00 -2.73470003e-02  8.13109994e-01  7.74169981e-01
#  -2.56390005e-01 -1.15759999e-01 -1.19819999e-01 -2.13630006e-01
#   2.84289997e-02  2.72610009e-01  3.10260002e-02  9.67819989e-02
#   6.77690003e-03  1.40819997e-01 -1.30639998e-02 -2.96860009e-01
#  -7.99129978e-02  1.94999993e-01  3.15489992e-02  2.85059988e-01
#  -8.74610022e-02  9.06109996e-03 -2.09889993e-01  5.39130010e-02]

# %%
print(X_train['image_id'])
# Out:
# 28698    abstract_v002_train2015_000000016721.png
# 8522     abstract_v002_train2015_000000012888.png
# 8017     abstract_v002_train2015_000000014923.png
# 43876    abstract_v002_train2015_000000014320.png
# 30907    abstract_v002_train2015_000000014085.png
#                            ...
# 35378    abstract_v002_train2015_000000007355.png
# 56392    abstract_v002_train2015_000000010309.png
# 32087    abstract_v002_train2015_000000013969.png
# 37397    abstract_v002_train2015_000000017516.png
# 6377     abstract_v002_train2015_000000010479.png
# Name: image_id, Length: 45197, dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = '/content/drive/MyDrive/VQA Notebooks/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def Dataset(colab_path, que, image_id, y, shape):

  img = cv2.imread(os.path.join(colab_path,image_id))
  img = cv2.resize(img, (224, 224), interpolation=cv2.INTER_NEAREST)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  image_vector = (img/255.0).astype(np.float32)

  que_vector = (pad_sequences(t.texts_to_sequences([que]), maxlen=22, padding='post'))[0]
  que_vector = np.asarray(que_vector).astype(np.float32)

  y = tf.one_hot(tf.cast(int(y), tf.uint8), 300)
  y = np.asarray(y).astype(np.float32)

  return que_vector,image_vector,y

# %%
def Dataset(colab_path, que, image_id, y, shape):

  img = cv2.imread(os.path.join(colab_path, image_id))
  if img is None:
      print(f"Error: Image {image_id} not found in path {colab_path}")
      return None, None, None

  img = cv2.resize(img, (shape, shape), interpolation=cv2.INTER_NEAREST)


  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  image_vector = (img / 255.0).astype(np.float32)

  que_vector = (pad_sequences(t.texts_to_sequences([que]), maxlen=22, padding='post'))[0]
  que_vector = np.asarray(que_vector).astype(np.float32)

  y = tf.one_hot(tf.cast(int(y), tf.uint8), 300)
  y = np.asarray(y).astype(np.float32)

  return que_vector, image_vector, y
test_image = []
test_que = []
Y_test = []

for i in tqdm(range(len(X_test))):
    que, image, y = Dataset(colab_path, list(X_test['question_preprocessed'])[i], list(X_test['image_id'])[i], list(y_test)[i], 224)
    if image is not None:
        test_image.append(image)
        test_que.append(que)
        Y_test.append(y)

test_image = np.asarray(test_image).astype(np.float32)
test_que = np.asarray(test_que).astype(np.float32)
Y_test = np.asarray(Y_test).astype(np.float32)

print(f"test_image shape: {test_image.shape}")
# Out:
#   9%|▉         | 462/5022 [00:07<01:18, 57.87it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-bc42b5f5dc4b> in <cell line: 26>()
#      25
#      26 for i in tqdm(range(len(X_test))):
# ---> 27     que, image, y = Dataset(colab_path, list(X_test['question_preprocessed'])[i], list(X_test['image_id'])[i], list(y_test)[i], 224)
#      28     if image is not None:
#      29         test_image.append(image)
#
# <ipython-input-66-bc42b5f5dc4b> in Dataset(colab_path, que, image_id, y, shape)
#       1 def Dataset(colab_path, que, image_id, y, shape):
#       2
# ----> 3   img = cv2.imread(os.path.join(colab_path, image_id))
#       4   if img is None:
#       5       print(f"Error: Image {image_id} not found in path {colab_path}")
#
# KeyboardInterrupt:

# %%
save_path = "/content/drive/MyDrive/VQA assignment/vqa_test_data_new.npz"

# Save the arrays in a single .npz file
np.savez(save_path, test_image=test_image, test_que=test_que, Y_test=Y_test)

print("Data saved successfully at", save_path)
# Out:
# Data saved successfully at /content/drive/MyDrive/VQA assignment/vqa_test_data_new.npz

# %%
import numpy as np

load_path = "/content/drive/MyDrive/VQA assignment/vqa_test_data_new.npz"


data = np.load(load_path)


test_image = data['test_image']
test_que = data['test_que']
Y_test = data['Y_test']

# %%
Y_test

# %%
test_que

# %%
test_image

# %%
test_image.shape

# %%
# importing necessary libraries
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, LSTM, Multiply
from tensorflow.keras.models import Model

# Load pre-trained VGG19 model
pre_trained_model = tf.keras.applications.VGG19(input_shape=(224, 224, 3), include_top=True, weights="imagenet", pooling='avg')
for layer in pre_trained_model.layers:
    layer.trainable = False

# Add regularizer to layers if applicable
regularizer = tf.keras.regularizers.l2(0.01)
for layer in pre_trained_model.layers:
    for attr in ['kernel_regularizer']:
        if hasattr(layer, attr):
            setattr(layer, attr, regularizer)

# Image feature extraction branch
vgg19_fc2_output = (pre_trained_model.get_layer('fc2')).output
img = Dense(units=1024, activation='relu', kernel_initializer='he_normal')(vgg19_fc2_output)
img = Dropout(0.2)(img)

# Question feature extraction branch
input_layer_que = Input(shape=(22,))
embedding = Embedding(vocab_size, 300, weights=[embedding_matrix_vocab], input_length=22, trainable=False)(input_layer_que)
lstm1 = LSTM(64, return_sequences=True)(embedding)
dropout1 = Dropout(0.5)(lstm1)
lstm2 = LSTM(64)(dropout1)
dropout2 = Dropout(0.5)(lstm2)
que = Dense(units=1024, activation='relu', kernel_initializer='he_normal')(dropout2)

# Element-wise multiplication of image and question features
pointwise_mul = Multiply()([que, img])

# Output layer
output = Dense(units=300, activation='softmax', kernel_initializer="glorot_uniform")(pointwise_mul)

# Define the complete model
model_lstm_vgg19 = Model(inputs=[input_layer_que, pre_trained_model.input], outputs=output)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model_lstm_vgg19.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model_lstm_vgg19.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1 (Conv2D)     │ (None, 224, 224, 64)   │          1,792 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2 (Conv2D)     │ (None, 224, 224, 64)   │         36,928 │ block1_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_pool               │ (None, 112, 112, 64)   │              0 │ block1_conv2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_conv1 (Conv2D)     │ (None, 112, 112, 128)  │         73,856 │ block1_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_conv2 (Conv2D)     │ (None, 112, 112, 128)  │        147,584 │ block2_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_pool               │ (None, 56, 56, 128)    │              0 │ block2_conv2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv1 (Conv2D)     │ (None, 56, 56, 256)    │        295,168 │ block2_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv2 (Conv2D)     │ (None, 56, 56, 256)    │        590,080 │ block3_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv3 (Conv2D)     │ (None, 56, 56, 256)    │        590,080 │ block3_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv4 (Conv2D)     │ (None, 56, 56, 256)    │        590,080 │ block3_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_pool               │ (None, 28, 28, 256)    │              0 │ block3_conv4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv1 (Conv2D)     │ (None, 28, 28, 512)    │      1,180,160 │ block3_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv2 (Conv2D)     │ (None, 28, 28, 512)    │      2,359,808 │ block4_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv3 (Conv2D)     │ (None, 28, 28, 512)    │      2,359,808 │ block4_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv4 (Conv2D)     │ (None, 28, 28, 512)    │      2,359,808 │ block4_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_pool               │ (None, 14, 14, 512)    │              0 │ block4_conv4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv1 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block4_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv2 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block5_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv3 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block5_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_3             │ (None, 22)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv4 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block5_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, 22, 300)        │      1,179,600 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_pool               │ (None, 7, 7, 512)      │              0 │ block5_conv4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_2 (LSTM)             │ (None, 22, 64)         │         93,440 │ embedding_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 25088)          │              0 │ block5_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 22, 64)         │              0 │ lstm_2[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc1 (Dense)               │ (None, 4096)           │    102,764,544 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_3 (LSTM)             │ (None, 64)             │         33,024 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc2 (Dense)               │ (None, 4096)           │     16,781,312 │ fc1[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 64)             │              0 │ lstm_3[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1024)           │      4,195,328 │ fc2[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1024)           │         66,560 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 1024)           │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 1024)           │              0 │ dense_4[0][0],         │
# │                           │                        │                │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 300)            │        307,500 │ multiply_1[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 145,445,692 (554.83 MB)
#  Trainable params: 4,695,852 (17.91 MB)
#  Non-trainable params: 140,749,840 (536.92 MB)

# %%
# Save the model to the specified path
save_path = '/content/drive/MyDrive/VQA assignment/my_vgg_model.h5'
model_lstm_vgg19.save(save_path)

print(f'Model saved at: {save_path}')

# %%
from tensorflow.keras.models import load_model

model_path = '/content/drive/MyDrive/VQA assignment/my_vgg_model.h5'

model_lstm_vgg19 = load_model(model_path)

print(f'Model loaded from: {model_path}')

# %%
model_lstm_vgg19 = model_lstm_vgg19.fit(
    traingen,
    batch_size=128,
    epochs=4,
    verbose=1,
    validation_data=valgen
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-86767606779a> in <cell line: 1>()
# ----> 1 model_lstm_vgg19 = model_lstm_vgg19.fit(
#       2     traingen,
#       3     batch_size=128,
#       4     epochs=4,
#       5     verbose=1,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# <ipython-input-74-79690c36e663> in __getitem__(self, index)
#      49
#      50         X0_batch = np.asarray([self.__get_input1(que) for que in batch_x0])
# ---> 51         X1_batch = np.asarray([self.__get_input2(colab_path+path) for path in batch_x1])
#      52         y_batch = np.asarray([self.__get_output(c) for c in batch_y])
#      53
#
# <ipython-input-74-79690c36e663> in <listcomp>(.0)
#      49
#      50         X0_batch = np.asarray([self.__get_input1(que) for que in batch_x0])
# ---> 51         X1_batch = np.asarray([self.__get_input2(colab_path+path) for path in batch_x1])
#      52         y_batch = np.asarray([self.__get_output(c) for c in batch_y])
#      53
#
# <ipython-input-74-79690c36e663> in __get_input2(self, path)
#      29             img = aug1.augment_image(img)
#      30         elif a<0.5:
# ---> 31             img = aug2.augment_image(img)
#      32         elif a<0.75:
#      33             img = aug3.augment_image(img)
#
# /usr/local/lib/python3.10/dist-packages/imgaug/augmenters/meta.py in augment_image(self, image, hooks)
#     761         """
#     762         assert ia.is_np_array(image), (
# --> 763             "Expected to get a single numpy array of shape (H,W) or (H,W,C) "
#     764             "for `image`. Got instead type %d. Use `augment_images(images)` "
#     765             "to augment a list of multiple images." % (
#
# TypeError: %d format: a real number is required, not str
